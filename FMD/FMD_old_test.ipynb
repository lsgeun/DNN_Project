# %% [markdown]
# # FMD 초기화

# %%
from FMD_old import FMD as FMD_old

fmd_old = FMD_old("/Volumes/My Passport_ssd_sg3/data_sets/cifar10/truck")

# %%
fmd_old.fit()

# %% [markdown]
# # 평가 데이터 평가하기

# %%
fmd_old.eval()

# %% [markdown]
# # FMD 속성 보여주기

# %%
# fmd_old.show_data_infos()

# %%
# fmd_old.show_FM_repres()

# %%
# fmd_old.show_AMs_and_related()

# %%
# fmd_old.show_dirs()

# %%
# fmd_old.show_layer_infos()

# %%
# fmd_old.show_eval_infos()

# %%
fmd_old.show_fmds_box_plot()

# %%
# fmd_old.show_fmdc()

# %% [markdown]
# # fmd-정분류 비율 그래프 보여주기

# %%
fmd_old.show_fmd_right_ratio_graph()

# %% [markdown]
# # 혼동 행렬 초기화 후 효과성 보여주기

# %%
fmd_old.set_CM_infos()

# %%
fmd_old.show_eval_venn_diagrams()

# %%
fmd_old.show_efficience_and_FMD_ratio()
# Out:
# In rotation_90
# [오분류 비율 U = WR_U(N)] = 0.226
# [오분류 비율 FMD = WR_FMD(NPV)] = 0.26157407407407407
#
# [긍정적 정밀성(TPR)] = 0.1757105943152455
# [부정적 정밀성(TNR)] = 1.0
# ------------------------------
# [정밀성 합] = 1.1757105943152455
#
# [FMD 비율(|eval_FMD|/|eval_U|)] = 0.638
# ------------------------------
# In brightness_10
# [오분류 비율 U = WR_U(N)] = 0.214
# [오분류 비율 FMD = WR_FMD(NPV)] = 0.23981900452488686
#
# [긍정적 정밀성(TPR)] = 0.1450381679389313
# [부정적 정밀성(TNR)] = 0.9906542056074766
# ------------------------------
# [정밀성 합] = 1.135692373546408
#
# [FMD 비율(|eval_FMD|/|eval_U|)] = 0.672
# ------------------------------
# In whiteness_10
# [오분류 비율 U = WR_U(N)] = 0.17
# [오분류 비율 FMD = WR_FMD(NPV)] = 0.1945080091533181
#
# [긍정적 정밀성(TPR)] = 0.15180722891566265
# [부정적 정밀성(TNR)] = 1.0
# ------------------------------
# [정밀성 합] = 1.1518072289156627
#
# [FMD 비율(|eval_FMD|/|eval_U|)] = 0.704
# ------------------------------

# %%
# show_all_mask = {'show_dirs': True,
                #   'show_data_infos': True,
                #   'show_hyper_parameter': True,
                #   'show_FM_repres': True,
                #   'show_AMs_and_related': True,
                #   'show_layer_infos': True,
                #   'show_fmds_box_plot': True,
                #   'show_fmdc': True,
                #   'show_eval_infos': True,
                #   'show_fmd_right_ratio_graph': True,
                #   'show_eval_venn_diagrams': True,
                #   'show_efficience_and_FMD_ratio': True,}
# fmd_old.show_all(show_all_mask)
