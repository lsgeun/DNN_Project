# %% [markdown]
# # FMD 초기화

# %%
from FMD import FMD
fmd1 = FMD("/Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane")

# %%
fmd1.fit()

# %% [markdown]
# # 평가 데이터 평가하기

# %%
fmd1.eval()

# %% [markdown]
# # FMD 속성 보여주기

# %%
fmd1.show_data_infos()
# Out:
# self.origin_names
# ['train', 'rtest', 'wtest']
# self.origin_K
# {'train': 5000, 'rtest': 771, 'wtest': 229}
# self.eval_names
# ['rotation_90', 'brightness_10', 'whiteness_10']
# self.eval_K
# {'rotation_90': 2000, 'brightness_10': 2000, 'whiteness_10': 2000}
# self.L
# 18
# self.shape
# [[32, 16], [32, 16], [32, 16], [32, 16], [32, 16], [32, 16], [16, 32], [16, 32], [16, 32], [16, 32], [16, 32], [16, 32], [8, 64], [8, 64], [8, 64], [8, 64], [8, 64], [8, 64]]

# %%
# fmd1.set_square_NPs_infos([20,60],column=7)
# fmd1.show_FM_repres()

# %%
# fmd1.set_square_NPs_infos([20,60],column=7)
# fmd1.show_AMs_and_related()

# %%
fmd1.show_dirs()
# Out:
# self.root_dir
# /Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane
# self.origin_dir
# /Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane/origin
# self.train_dir
# /Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane/origin/train
# self.rtest_dir
# /Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane/origin/rtest
# self.wtest_dir
# /Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane/origin/wtest
# self.eval_dir
# /Volumes/My Passport_ssd_sg3/data_sets/cifar10/airplane/eval

# %%
fmd1.set_square_NPs_infos([50,10])
fmd1.show_eval_infos()
# Out:
# In eval/rotation_90
# self.eval_U[rotation_90] self.is_eval_FMD[rotation_90] self.fmds[rotation_90]
#
# In eval/brightness_10
# self.eval_U[brightness_10] self.is_eval_FMD[brightness_10] self.fmds[brightness_10]
#
# In eval/whiteness_10
# self.eval_U[whiteness_10] self.is_eval_FMD[whiteness_10] self.fmds[whiteness_10]

# %%
fmd1.show_fmdc()
# Out:
# self.fmdc
# 90.64331213160139

# %% [markdown]
# # 혼동 행렬 초기화 후 효과성 보여주기

# %%
fmd1.set_CM_infos()

# %%
fmd1.show_CM_venn_diagrams()

# %%
fmd1.show_efficience_and_FMD_ratio()
# Out:
# In rotation_90
# FMD 부정적 정확성(NPV) = 0.33333333333333337 <= 0.3365 = U 부정적 정확성(N)
# --------------------------------------------------
# FN = 0.15 >= 0.1478826151560178 = TN * P / N
#
# 부정적 정밀성(TNP) = 0.22288261515601782
# --------------------------------------------------
# FP = 0.2615
#
# In brightness_10
# FMD 부정적 정확성(NPV) = 0.2776659959758552 <= 0.326 = U 부정적 정확성(N)
# --------------------------------------------------
# FN = 0.1795 >= 0.1426564417177914 = TN * P / N
#
# 부정적 정밀성(TNP) = 0.2116564417177914
# --------------------------------------------------
# FP = 0.257
#
# In whiteness_10
# FMD 부정적 정확성(NPV) = 0.3021739130434783 <= 0.316 = U 부정적 정확성(N)
# --------------------------------------------------
# FN = 0.1605 >= 0.1504367088607595 = TN * P / N
#
# 부정적 정밀성(TNP) = 0.2199367088607595
# --------------------------------------------------
# FP = 0.2465

# %%
import numpy as np

a = np.array([1,2,3,4])
a[len(a)//2]
# Out:
# 3
