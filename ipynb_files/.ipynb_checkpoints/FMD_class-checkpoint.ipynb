# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import pickle
import copy

import time
from datetime import timedelta

'''
각 레이어에서 '훈련 피처 맵'과 '정분류 테스트 피처 맵'과 '오분류 테스트 피처 맵'은 모두 같은 형태이어야 한다.
예를 들어, 첫번째 레이어에서 훈련 피처 맵(100, 12, 12) 정분류 테스트 피처 맵(30, 12, 12), 오분류 테스트 피처 맵(20, 12, 12)
와 같이 인덱스 첫번째인 개수는 다르더라도 이차 넘파이 배열은 같아야 한다.
'''

class FMD():
    # directory
    # root_dir: 관련된 데이터가 모두 저장되어 있는 디렉토리 경로
    # origin_dir: train, rtest, wtest가 있는 디렉토리
    # eval_dir: 거리를 잴 데이터가 있는 디렉토리
    root_dir=""; origin_dir=""; eval_dir=""

    # data_infos
    # 데이터 타입에 대한 이름
    origin_names = ["train", "rtest", "wtest"]
    eval_names = []
    # (이하) 대괄호로 쳐져있는 배열은 나중에 넘파이 배열이 될 수 있다.
    # (origin_, eval_)K: 피처 맵의 개수, L: 레이어의 개수(0~L-1는 각 레이어의 인덱스)
    # shape: 레이어의 넘파이 모양
    # 아래 (origin_, eval_)K, L, shape을 'data_infos'라고 하자.
    # min max은 정규화된 데이터의 최소값과 최대값을 의미한다.
    origin_K={"train": 0, "rtest": 0, "wtest": 0}; eval_K={}; L=0; shape=[]
    
    # FM_means
    # (이하) 훈련 데이터, 정분류 테스트 데이터, 오분류 테스트 데이터에서 데이터라는 용어를 생략하고 적었다.
    # 아래의 배열들은 모두 파이썬 배열이고 첫 번째 인자에 layer가 들어간다.
    # TFM_mean: 훈련 평균 피처 맵(베이스 피처 맵)
    # RFM_mean: 정분류 테스트 평균 피처 맵
    # WFM_mean: 오분류 테스트 평균 피처 맵
    TFM_mean=[]; RFM_mean=[]; WFM_mean=[]

    # AMs와 그와 관련된 것
    # TAM: 훈련 활성화 피처 맵       , RAM: 정분류 테스트 활성화 피처 맵
    # WAM: 오분류 테스트 활성화 피처 맵
    TAM=[]; RAM=[]; WAM=[]
    # alpha는 거리 계산을 위한 인덱스를 고르기 위해 필요한 변수이다.
    # w_minus_r_max(= max(w-r))는 나중에 alpha 값에 의존하여 최대로 만들어진다.
    # alpha_min, alpha_max는 각 레이어에서의 alpha가 가질 수 있는 최소값 최대값을 나타낸 것이다.
    # [hyper parameter] alpha_slice은 alpha_min에서 alpha_max로 몇 번의의 간격으로 도착할지 알려주는 변수임.
    alpha=[]; alpha_slice=[]; w_minus_r_max=[]
    alpha_min=[]; alpha_max=[]
    # DAM_indexes는 나중에 거리 계산할 때 쓰이는 다차원 인덱스들의 집합이다.
    # 각 원소는 피처 맵의 한 원소의 인덱스를 나타낸다.
    # DAM: 거리 활성화 맵, DAM는 거리 계산을 위한 인덱스만 활성된 맵이다.
    # 각 레이어마다 튜플들 세트가 있어야 함. np.array의 item 메소드를 사용할 것이기 때문
    # [hyper parameter] DAM_select는 DAM를 고르는 방법을 알려줌.
    DAM_indexes=[]; DAM=[]; DAM_select=[]

    # index_infos
    '''
    사용하지 않음.
    '''
    # '오분류 테스트' 각 인덱스에서의 거리에 대한 중간값, 평균, 표준편차, 최소값, 최대값에 대한 배열은
    # 각 mid, mean, std, min, max임
    # 인덱스마다 달라지는 값이니 총칭해서 'index_infos'라고 하자.
    mid=[]; mean=[]; std=[]; min=[]; max=[]
    
    # layer_infos
    '''
    사용하지 않음.
    lfmd_select: 레이어 피처맵 거리 계산 방법
    [hyper parameter] lfmd_select는 각 레이어에 대한 피처 맵을 구하는 방법을 저장한다.
    '''
    lfmd_select=[]
    # W: 레이어 피처맵 거리 가중치
    # [hyper parameter] W는 각 레이어의 피처 맵에 곱할 weight 중요도이다
    # 레이어 피처 맵에 대한 가시적인 출력을 위해 1차 이상의 배열을 2차원 배열로 바꿈
    # square_FM_side은 1차 이상의 배열을 2차원 배열로 바꾸기 위해 필요한 2차원 배열의 한 변의 길이임.
    square_FM_side=[]; W=[]

    # fmdc
    # fmdc 피처 맵 거리 기준으로 어떤 데이터가 나중에 오분류 될 거 같은지 판단함.
    # fmdc는 거리이므로 음수가 될 수 없음, 따라서, fmdc가 -1이라는 것은 아직 계산하지 않았다는 의미임.
    fmdc=-1

    def __init__(self, root_dir_=""):
        # root 디렉토리 입력이 없다면 return
        if root_dir_=="":
            print("루트 디렉토리 경로를 설정해주세요.")
            return
        # root 디렉토리
        self.root_dir = root_dir_

        # origin 디렉토리
        self.origin_dir = f"{self.root_dir}/origin"
        # 훈련을 저장하는 디렉토리
        self.train_dir=f"{self.origin_dir}/{self.origin_names[0]}"
        # 정분류 테스트를 저장하는 디렉토리
        self.rtest_dir=f"{self.origin_dir}/{self.origin_names[1]}"
        # 오분류 테스트를 저장하는 디렉토리
        self.wtest_dir=f"{self.origin_dir}/{self.origin_names[2]}"
        
        # eval 디렉토리
        self.eval_dir = f"{self.root_dir}/eval"

        # os.paht.isdir는 '\ ' 대신, ' '을 써도 됨
        is_there_instances = os.path.isdir(f"{self.root_dir}/instances")
        # 객체를 불러오거나 저장할 디렉토리 생성
        # ' '을 '\ '로 바꿈
        root_dir = self.root_dir.replace(' ', '\ ')
        # instances 디렉토리가 없을 경우만 instances 생성
        if not is_there_instances:
            os.system(f"mkdir {root_dir}/instances")

    def fit(self):
        # 객체의 속성 초기화
        # root_dir의 데이터가 올바르다면 init이 에러 없이 완료됨
        self.set_data_infos()
        self.set_FM_means()
        self.set_AMs()
        # self.set_index_infos()
        self.set_fmdc()

    def set_root_dir(self, root_dir_):
        self.root_dir = root_dir_

        # origin 디렉토리
        self.origin_dir = f"{self.root_dir}/origin"
        # 훈련을 저장하는 디렉토리
        self.train_dir=f"{self.origin_dir}/{self.origin_names[0]}"
        # 정분류 테스트를 저장하는 디렉토리
        self.rtest_dir=f"{self.origin_dir}/{self.origin_names[1]}"
        # 오분류 테스트를 저장하는 디렉토리
        self.wtest_dir=f"{self.origin_dir}/{self.origin_names[2]}"
        
        # eval 디렉토리
        self.eval_dir = f"{self.root_dir}/eval"

    def create_practice(self):
        '''
        아마도 나중에 adapter를 만들 때 사용될 수 있을 것 같음.
        '''

        # 연습 데이터 랜덤 시드 설정
        random_seed_id = 42
        np.random.seed(random_seed_id)
        # 연습 데이터 범위 설정
        '''
        연습 데이터 범위가 0~1로로 고정, np.random.rand(or random)으로 바로 구현 가능
        '''
        # random_start = 1; random_end = 2

        # 디렉토리 설정
        root_dir = "practice"
        origin_dir = f"{root_dir}/origin"
        eval_dir = f"{root_dir}/eval"
        # 디렉토리 생성
        os.system(f"mkdir {root_dir}")
        os.system(f"mkdir {origin_dir}")
        os.system(f"mkdir {eval_dir}")

        # origin 데이터 종류 적기
        origin_names="train rtest wtest"
        # origin_K 각 데이터 종류마다의 개수
        origin_K="10000 2000 4000"
        # eval 데이터 종류 적기
        eval_names="rotation_90 brightness_10 whiteness_10"
        # eval_K 각 데이터 종류마다의 개수
        eval_K="12000 4000 6000"
        # L: 레이어의 개수, shape: 레이어의 모양
        L="3";
        shape = "12 12" + "\n"
        shape += "12 2 3 4" + "\n"
        shape += "24 8"

        # data_infos.txt 파일로 저장
        # origin 데이터 종류는 train rtest wtest로 이미 정해져 있으므로 파일에 저장하지 않음
        os.system(f"touch {root_dir}/data_infos.txt")
        data_infos_txt = open(f"{root_dir}/data_infos.txt", 'w')
        data_infos_txt.write(origin_K + "\n")
        data_infos_txt.write(eval_names + "\n")
        data_infos_txt.write(eval_K + "\n")
        data_infos_txt.write(L + "\n")
        data_infos_txt.write(shape)
        data_infos_txt.close()

        # 자료구조를 바꾸어 for문 활용을 쉽게 하기
        origin_names = origin_names.split()
        origin_K = list(map(int,origin_K.split()))
        origin_K_list = origin_K
        origin_K = {}
        for i in range(len(origin_names)):
            origin_K[origin_names[i]] = origin_K_list[i]
        
        eval_names = eval_names.split()
        eval_K = list(map(int,eval_K.split()))
        eval_K_list = eval_K
        eval_K = {}
        for i in range(len(eval_names)):
            eval_K[eval_names[i]] = eval_K_list[i]

        L=int(L)
        
        shape = shape.split('\n')
        for ith in range(len(shape)):
            shape[ith] = list(map(int,shape[ith].split()))

        # origin 연습 데이터 생성
        for origin_name in origin_names:
            os.system(f"mkdir {origin_dir}/{origin_name}")
            # datas: 데이터들을 최대 1000개씩 담음.
            # file_index: 0 ~ K-1 까지 파일을 1000개씩 담을건데 0에서부터 시작해서 1000개마다 1 증가함
            datas = []; file_index = 0

            for k in range(origin_K[origin_name]):
                # data: 데이터는 레이어들을 담고 있음
                data = []
                # data에 레이어들을 담은 후
                for l in range(L):
                    lth_layer = np.random.random(shape[l])
                    data.append(lth_layer)
                # datas에 레이어들을 담은 data를 담음
                datas.append(data)

                # 1000개마다 데이터가 저장됨
                if len(datas) == 1000:
                    # file_index번째 datas를 저장
                    with open(f'{origin_dir}/{origin_name}/{origin_name}_{file_index}.pickle', 'wb') as f:
                        pickle.dump(datas, f, pickle.HIGHEST_PROTOCOL)
                    # datas의 데이터를 램에서 제거
                    del datas
                    # datas를 빈 배열로 만듦
                    datas = []
                    # 파일 인덱스 1 증가
                    file_index += 1

            # datas의 데이터가 남아있다면, 1~999개의 데이터가 남아있다면 그 데이터도 마저 저장함
            if len(datas) != 0:
                with open(f'{origin_dir}/{origin_name}/{origin_name}_{file_index}.pickle', 'wb') as f:
                    pickle.dump(datas, f, pickle.HIGHEST_PROTOCOL)

            # 훈련 데이터의 경우
            # 정분류(1), 오분류(0) 여부를 알려주는 넘파이 배열을 파일로 저장함
            if origin_name == "train":
                origin_result = np.random.randint(0,2, origin_K[origin_name])
                # 1 -> True, 0 -> False로 변경
                origin_result = np.array(origin_result, dtype="bool")
                np.save(f"{origin_dir}/{origin_name}/{origin_name}_result.npy", origin_result)

        # eval 연습 데이터 생성
        for eval_name in eval_names:
            os.system(f"mkdir {eval_dir}/{eval_name}")
            # datas: 데이터들을 최대 1000개씩 담음.
            # file_index: 0 ~ K-1 까지 파일을 1000개씩 담을건데 0에서부터 시작해서 1000개마다 1 증가함
            datas = []; file_index = 0

            for k in range(eval_K[eval_name]):
                # data: 데이터는 레이어들을 담고 있음
                data = []
                # data에 레이어들을 담은 후
                for l in range(L):
                    lth_layer = np.random.random(shape[l])
                    data.append(lth_layer)
                # datas에 레이어들을 담은 data를 담음
                datas.append(data)

                # 1000개마다 데이터가 저장됨
                if len(datas) == 1000:
                    # file_index번째 datas를 저장
                    with open(f'{eval_dir}/{eval_name}/{eval_name}_{file_index}.pickle', 'wb') as f:
                        pickle.dump(datas, f, pickle.HIGHEST_PROTOCOL)
                    # datas의 데이터를 램에서 제거
                    del datas
                    # datas를 빈 배열로 만듦
                    datas = []
                    # 파일 인덱스 1 증가
                    file_index += 1

            # datas의 데이터가 남아있다면, 1~999개의 데이터가 남아있다면 그 데이터도 마저 저장함
            if len(datas) != 0:
                with open(f'{eval_dir}/{eval_name}/{eval_name}_{file_index}.pickle', 'wb') as f:
                    pickle.dump(datas, f, pickle.HIGHEST_PROTOCOL)

            # 정분류(1), 오분류(0) 여부를 알려주는 넘파이 배열을 파일로 저장함
            eval_result = np.random.randint(0,2, eval_K[eval_name])
            # 1 -> True, 0 -> False로 변경
            eval_result = np.array(eval_result, dtype="bool")
            np.save(f"{eval_dir}/{eval_name}/{eval_name}_result.npy", eval_result)

    def set_data_infos(self):
        # root dir의 data_infos.txt 열기
        data_infos = open(f"{self.root_dir}/data_infos.txt", 'r')
        data_infos_strs = data_infos.read()
        data_infos_str_list = data_infos_strs.split('\n')
        # 0th: origin_K 
        origin_K = list(map(int, data_infos_str_list[0].split()))
        origin_name_K_zip = zip(self.origin_names, origin_K) 
        for origin_name, origin_K in origin_name_K_zip:
            self.origin_K[origin_name] = origin_K
        # 1th: eval_names
        self.eval_names = data_infos_str_list[1].split()
        # 2th: eval_K
        eval_K = list(map(int, data_infos_str_list[2].split()))
        eval_name_K_zip = zip(self.eval_names, eval_K) 
        for eval_name, eval_K in eval_name_K_zip:
            self.eval_K[eval_name] = eval_K
        # 3th: L
        self.L = int(data_infos_str_list[3])
        # 4+0th ~ 4+(L-1)th: shape
        for l in range(self.L):
            shape_l = list(map(int,data_infos_str_list[4+l].split()))
            self.shape.append(shape_l)
        # root dir의 data_infos.txt 닫기
        data_infos.close()

        # 레이어 피처 맵을 구하는 방식을 se_lfmd 모두 통일
        '''
        for l in range(self.L):
            self.lfmd_select.append("se_lfmd")
        '''
        # W를 균등하게 만듦
        for l in range(self.L):
            self.W.append(1/self.L)

    def set_FM_means(self):
        # 인스턴스 속성을 변수로 포인터처럼 가르킴
        train = self.origin_names[0]; rtest = self.origin_names[1]; wtest = self.origin_names[2]
        L = self.L; shape = self.shape

        def set_FM_mean(origin):
            # 인스턴스 속성을 변수로 포인터처럼 가르킴
            origin_K = self.origin_K[origin]

            if origin == train:
                OFM_mean = self.TFM_mean; origin_dir = self.train_dir;
            elif origin == rtest:
                OFM_mean = self.RFM_mean; origin_dir = self.rtest_dir;
            elif origin == wtest:
                OFM_mean = self.WFM_mean; origin_dir = self.wtest_dir;
            else:
                print('잘못된 origin: ', origin, sep='')
                return

            # 각 레이어의 피처 맵을 0으로 초기화하여 생성
            for l in range(L):
                OFM_mean_l = np.zeros(shape[l])
                OFM_mean.append(OFM_mean_l)

            # OFMP_k는 k번째 origin 데이터가 속한 FMP임
            # k번 째 데이터의 OFMPI는 OFMPI_k = k // 1000임
            # k번 째 데이터의 OFMPO은 OFMPO_k = k % 1000임
            OFMP_k = None; prev_OFMPI_k = None; cur_OFMPI_k = None

            k = 0
            # 0번 째 데이터가 속한 OFMP_k를 불러들인 후
            prev_OFMPI_k = k // 1000
            OFMPO_k = k % 1000
            with open(f'{origin_dir}/{origin}_{prev_OFMPI_k}.pickle', 'rb') as f:
                OFMP_k = pickle.load(f)
            # 0번 째 데이터를 OFM_mean에 넣는다.
            for l in range(L):
                OFM_k_l = OFMP_k[OFMPO_k][l]
                OFM_mean[l] = OFM_mean[l] + OFM_k_l

            # k = 1 ~ K-1
            # 1~K-1번 째 데이터로 OFM_mean을 구한다.
            for k in range(1, origin_K):
                # k번 째 데이터의 OFMPI, OFMPO 구함
                cur_OFMPI_k = k // 1000
                OFMPO_k = k % 1000

                # OFMP_k가 이미 있다면 가지고 오지 않고
                #             없다면 이전 OFMP를 지우고 현재 OFMP를 가지고 온다.

                # cur_OFMPI_k와 prev_OFMPI_k가 같다면
                if cur_OFMPI_k == prev_OFMPI_k:
                    pass # 아무 작업 하지 않고

                # cur_OFMPI_k와 prev_OFMPI_k가 다를 경우
                else:
                    # 이전 OFMP_k의 기억공간을 램에서 제거한 후
                    del OFMP_k
                    # cur_OFMPI_k를 현재 OFMP_k를 가지고 온다.
                    with open(f'{origin_dir}/{origin}_{cur_OFMPI_k}.pickle', 'rb') as f:
                        OFMP_k = pickle.load(f)

                # prev_OFMPI_k를 cur_OFMPI_k로 초기화 
                prev_OFMPI_k = cur_OFMPI_k

                for l in range(L):
                    OFM_k_l = OFMP_k[OFMPO_k][l]
                    OFM_mean[l] = (OFM_mean[l]*k + OFM_k_l)/(k+1)

        # 훈련, 정분류 테스트, 오분류 테스트 데이터에 대한 FM_mean을 구함
        set_FM_mean(train); set_FM_mean(rtest); set_FM_mean(wtest)
        
    def set_AMs(self):
        # alpha, w_minus_r_max를 0으로 초기화
        self.alpha = np.zeros(self.L)
        self.w_minus_r_max = np.zeros(self.L)

        # [hyperparameter] alpha_slice를 일단 1000으로 함
        for l in range(self.L):
            self.alpha_slice.append(1000)

        # alpha의 최소값과 최대값을 구함
        self.alpha_min = np.zeros(self.L)
        self.alpha_max = np.zeros(self.L)
        for l in range(self.L):
            self.alpha_min[l] = np.array([self.RFM_mean[l].min(),
                                         self.TFM_mean[l].min(),
                                         self.WFM_mean[l].min()]).min()
            self.alpha_max[l] = np.array([self.RFM_mean[l].max(),
                                         self.TFM_mean[l].max(),
                                         self.WFM_mean[l].max()]).max()

        # TAM, RAM, WAM을 0으로 초기화 함
        for l in range(self.L):
            TAM_l = np.zeros(self.shape[l])
            self.TAM.append(TAM_l)
        for l in range(self.L):
            RAM_l = np.zeros(self.shape[l])
            self.RAM.append(RAM_l)
        for l in range(self.L):
            WAM_l = np.zeros(self.shape[l])
            self.WAM.append(WAM_l)

        # w-r가 최대가 되는 alpha, TAM, RAM, WAM을 찾음
        for l in range(self.L):
            # range 부분 고칠 필요가 있음
            a_min_l = self.alpha_min[l]; a_max_l = self.alpha_max[l]
            a_slice_l = self.alpha_slice[l]
            interval_l = (a_max_l - a_min_l)/a_slice_l
            # range(a_slice_l+1) 해야 a_min_l 부터 a_max_l 까지 감
            for alpha_l in [a_min_l + interval_l*s for s in range(a_slice_l+1)]:
                TAM_l = np.array(self.TFM_mean[l] > alpha_l)
                RAM_l = np.array(self.RFM_mean[l] > alpha_l)
                WAM_l = np.array(self.WFM_mean[l] > alpha_l)
                
                TAM_l_xor_RAM_l = np.logical_xor(TAM_l, RAM_l)
                TAM_l_xor_WAM_l = np.logical_xor(TAM_l, WAM_l)
                # r_l은 TAM_l과 RAM_l이 얼마나 유사하지 않은지 보여준다.
                # 즉, TAM_l과 RAM_l이 유사하지 않을수록 r_l 값이 커진다.
                # w_l도 마찬가지이다.
                r_l = len(np.where(TAM_l_xor_RAM_l == True)[0])
                w_l = len(np.where(TAM_l_xor_WAM_l == True)[0])
                
                if w_l - r_l > self.w_minus_r_max[l]:
                    # w-r가 이전의 w-r보다 클 때
                    # 즉, TAM과 RAM이 더 유사해지거나 TAM과 WAM이 더 다를 때
                    # alpha, w-r, TAM, RAM, WAM를 최신화함.
                    self.w_minus_r_max[l] = w_l - r_l
                    self.alpha[l] = alpha_l
                    self.TAM[l] = TAM_l
                    self.RAM[l] = RAM_l
                    self.WAM[l] = WAM_l

        # TAM, RAM, WAM를 이용하여 DAM를 구함
        # DAM에 WAM를 deep copy 복사함
        for l in range(self.L):
            DAM_l = self.WAM[l].copy()
            self.DAM.append(DAM_l)

        # [hyperparameter] 일단 모든 레이어를 'and' 방식으로 함
        for l in range(self.L):
            self.DAM_select.append("and")

        # 선택하려는 방식('and', 'or', 등등)대로 DAM를 고름
        for l in range(self.L):
            # 'and' 방식보다 'or' 방식에서 대부분의 인덱스에서 오분류 데이터의 값이 상대적으로 더 커짐
            # 다만 'or' 방식은 'and' 방식보다 거리 계산을 위한 인덱스의 개수가 더 줄어듦
            # 'all' 방식은 모든 인덱스를 다 사용함.
            if self.DAM_select[l] == "and":
                TAM_l_and_RAM_l = np.logical_and(self.TAM[l], self.RAM[l])
                # WAM에서 (TAM 교집합 RAM)과 곂치는 부분을 False로 만듦
                np.place(self.DAM[l], TAM_l_and_RAM_l, False)
            elif self.DAM_select[l] == "or":
                TAM_l_or_RAM_l = np.logical_or(self.TAM[l], self.RAM[l])
                # WAM에서 (TAM 합집합 RAM)과 곂치는 부분을 False로 만듦)
                np.place(self.DAM[l], TAM_l_or_RAM_l, False)
            elif self.DAM_select[l] == "all":
                not_DAM_l = np.logical_not(self.DAM[l])
                # 모든 인덱스를 다 사용함
                np.place(self.DAM[l], not_DAM_l, True)

        # DAM_indexes를 지정함
        for l in range(self.L):
            nonzero_DAM_l = np.nonzero(self.DAM[l])
            DAM_indexes_l = np.empty((1,len(nonzero_DAM_l[0])), dtype="int32")
            # l 레이어 차원의 수 만큼 각 차원에 대한 인덱스들을 DAM_indexes_l에 삽입
            for i in range(len(nonzero_DAM_l)):
                DAM_indexes_l = np.append(DAM_indexes_l, nonzero_DAM_l[i].reshape(1,-1), axis=0)
            # 처음 배열은 np.empty 메소드로 만들어진 쓰레기 값이라 버림
            # 가로 방향이라 세로 방향으로 길게 늘어지도록 바꿈
            DAM_indexes_l = list(DAM_indexes_l[1:].T)
            # DAM_indexes_l 각 원소가 리스트 형태인데 그것을 튜플로 바꿈
            # 튜플로 만드는 이유는 np.item() 메소드가 튜플을 인자로 받기 때문
            for i in range(len(DAM_indexes_l)):
                DAM_indexes_l[i] = tuple(DAM_indexes_l[i])

            self.DAM_indexes.append(DAM_indexes_l)
    
    # 아래의 방식을 쓴다면 거리 계산하기 전에 걸리는 시간도 길어지고 그다지 효율적이지도 않음.
    # 따라서 index_infos를 구하지 않음
    def set_index_infos(self):
        wtest = self.origin_names[2]

        for l in range(self.L):
            # mid_l, mean_l, std_l, min_l, max_l를 모두 -1로 초기화
            # 거리가 -1(음수)이 될 수 없으므로 -1인 부분은 초기화 되지 않은 인덱스 값임
            mid_l = np.zeros(self.shape[l]); mid_l = mid_l - 1
            mean_l = np.zeros(self.shape[l]); mean_l = mean_l - 1
            std_l = np.zeros(self.shape[l]); std_l = std_l - 1
            min_l = np.zeros(self.shape[l]); min_l = min_l - 1
            max_l = np.zeros(self.shape[l]); max_l = max_l - 1
            for DAM_index_l in self.DAM_indexes[l]:
                ED_array_l_DAM_index = np.empty((0), dtype="float")
                for k in range(self.origin_K[wtest]):
                    WFM_k_l = np.load(f"{self.wtest_dir}/{wtest}_{k}_{l}.npy")
                    # append를 많이 사용하면 속도가 줄어듦
                    ED_array_l_DAM_index = np.append(ED_array_l_DAM_index, abs(self.TFM_mean[l].item(DAM_index_l)
                                                                                 - WFM_k_l.item(DAM_index_l))) # TFM_mean = BFM

                mid_l.itemset(DAM_index_l, sorted(ED_array_l_DAM_index)[self.origin_K[wtest] // 2])
                mean_l.itemset(DAM_index_l, ED_array_l_DAM_index.mean())
                std_l.itemset(DAM_index_l, ED_array_l_DAM_index.std())
                min_l.itemset(DAM_index_l, ED_array_l_DAM_index.min())
                max_l.itemset(DAM_index_l, ED_array_l_DAM_index.max())

            self.mid.append(mid_l)
            self.mean.append(mean_l)
            self.std.append(std_l)
            self.min.append(min_l)
            self.max.append(max_l)
    # 사용하지 않음
    def md_lfmd(self, dir1, dir2, k, l):
        '''
        중앙값으로 나눠서 구한 레이어 거리(middle division layer feature map distance)

        dir1은 root 디렉토리 기준으로 깊이가 1인 것
        dir2은 root 디렉토리 기준으로 깊이가 2인 것
        k는 몇 번째 데이터인지 알려줌, l은 몇번째 레이어인지 알려줌
        예시: MDD("origin", "train", 1, 2)은
        root 디렉토리/origin/train/train_1_2에 대한 레이어 거리임.
        '''
        md_lfmd = 0
        dir2_FM_k_l = np.load(f'{self.root_dir}/{dir1}/{dir2}/{dir2}_{k}_{l}.npy')

        for index in self.DAM_indexes[l]:
            length_index = abs(self.TFM_mean[l].item(index) - dir2_FM_k_l.item(index))
            mid_index = self.mid[l].item(index)

            md_lfmd += (length_index / mid_index)**2
        
        return md_lfmd
    # 사용하지 않음
    def norm_lfmd(self, dir1, dir2, k, l):
        '''
        정규화를 시켜서 구한 레이어 거리(normal layer feature map distance)
        '''
        norm_lfmd = 0
        dir2_FM_k_l = np.load(f'{self.root_dir}/{dir1}/{dir2}/{dir2}_{k}_{l}.npy')
        
        for index in self.DAM_indexes[l]:
            length_index = abs(self.TFM_mean[l].item(index) - dir2_FM_k_l.item(index))
            mean_index = self.mean[l].item(index)
            std_index = self.std[l].item(index)

            norm_lfmd += math.exp((length_index - mean_index) / std_index)
        
        return norm_lfmd
    # 사용하지 않음
    def mms_lfmd(self, dir1, dir2, k, l):
        '''
        min-max으로 표준화한 후 shift하여 구한 레이어 거리(min max shift layer feature map distance)
        '''
        mms_lfmd = 0
        dir2_FM_k_l = np.load(f'{self.root_dir}/{dir1}/{dir2}/{dir2}_{k}_{l}.npy')
        
        for index in self.DAM_indexes[l]:
            length_index = abs(self.TFM_mean[l].item(index) - dir2_FM_k_l.item(index))
            mid_index = abs(self.TFM_mean[l].item(index) - self.mid[l].item(index))
            min_index = self.min[l].item(index)
            max_index = self.max[l].item(index)

            min_max_index = (length_index - min_index) / (max_index - min_index)
            min_max_mid_index = (mid_index - min_index) / (max_index - min_index)
            
            if length_index <= mid_index:
                mms_lfmd += (min_max_index + 0)**2
            else:
                mms_lfmd += (min_max_index + 1 - min_max_mid_index)**2
        
        return mms_lfmd
    
    def se_lfmd(self, FM_k_l, l, percent=50):
        '''
        se_lfmd: shift exponential layer feature map distance
        일단 디폴트로 length_min length_max의 50(정중앙 값)에 해당하는 부분을 origin(원점)으로 이동
        '''
        se_lfmd = 0
        
        # self.TFM_mean[l], FM_k_l를 norm_min, norm_max으로 정규화
        # norm_min과 norm_max을 1. 속성으로 두거나 2. 형식 매개변수로 둬도 되는데 3. 일단 지역 변수로 두자.
        # 이것도 [hyper parameter]가 될 수도 있겠다.
        norm_min = -1; norm_max = 1
        TFM_mean_l_norm = self.normalize_layer(self.TFM_mean[l], norm_min, norm_max)
        FM_k_l_norm = self.normalize_layer(FM_k_l, norm_min, norm_max)

        # lengths: 인덱스 마다 TFM_mean_norm과 FM_k_l_norm 사이의 거리(절대값)를 구함
        lengths = abs(TFM_mean_l_norm - FM_k_l_norm)
        
        # 'shift_value'을 구함
        # norm_min, norm_max가 같은 두 값의 길이의 min(length_min)은 0이고
        # length_max는 norm_max - norm_min임
        length_max = norm_max - norm_min; length_min = 0
        # 
        length_interval_max = length_max - length_min
        length_interval_percent = length_interval_max * (percent/100)
        # value_to_be_origin는 나중에 원점이 될 값임
        value_to_be_origin = length_min + length_interval_percent
        # shift_value는 value_to_be_origin을 0으로 옮기기 위한 이동 값임
        shift_value = -value_to_be_origin

        # 각 원소를 shift value 만큼 이동시키고 'exponential'을 취함
        for index in self.DAM_indexes[l]:
            exp_lengths_minus_shift_value = np.exp(lengths - shift_value)
        # se를 취한 값들을 모두 더한 것이 se_lfmd임
        se_lfmd = exp_lengths_minus_shift_value.sum()
        
        return se_lfmd
    
    def normalize_layer(self, layer, min, max):
        '''
        'layer의 min, max'으로 layer를 'min-max 정규화'를 한 후
        최소값이 min, 최대값이 max가 되도록 layer를 정규화 한다.
        layer(넘파이)에 스칼라 곱셈과 스칼라 덧셈을 적용하여 구현할 수 있다.
        '''
        # 'layer의 min, max'으로 layer를 'min-max 정규화'
        layer_min = layer.min(); layer_max = layer.max();
        # layer 값들이 하나라도 다르다면
        if layer_max - layer_min != 0:
            layer = (layer - layer_min) / (layer_max - layer_min)
        # layer 값들이 모두 같다면
        else:
            layer = 0

        scalar_multiplyer = max - min
        scalar_adder = min

        normalized_layer = scalar_multiplyer*layer + scalar_adder

        return normalized_layer
    
    def ab_lfmd(self, FM_k_l, l):
        '''
        ab_lfmd: absolute layer feature map distance
        레이어의 인덱스들 간의 절대값을 모두 더한다.
        '''
        ab_lfmd = 0
        
        # self.TFM_mean[l], FM_k_l를 norm_min, norm_max으로 정규화
        # norm_min과 norm_max을 1. 속성으로 두거나 2. 형식 매개변수로 둬도 되는데 3. 일단 지역 변수로 두자.
        # 이것도 [hyper parameter]가 될 수도 있겠다.
        norm_min = -1; norm_max = 1
        TFM_mean_l_norm = self.normalize_layer(self.TFM_mean[l], norm_min, norm_max)
        FM_k_l_norm = self.normalize_layer(FM_k_l, norm_min, norm_max)

        # lengths: 인덱스 마다 TFM_mean_norm과 FM_k_l_norm 사이의 거리(절대값)를 구함
        lengths = abs(TFM_mean_l_norm - FM_k_l_norm)
        
        # ed를 취한 값들을 모두 더한 것이 se_lfmd임
        ab_lfmd = lengths.sum()
        
        return ab_lfmd

    def fmd(self, FM_k):
        # 피처 맵 거리를 0으로 초기화
        fmd=0
        # lfmds: 레이어 피처 맵 거리를 담는 곳
        lfmds=[]
        # 각 레이어에 대한 레이어 피처 맵 거리 계산법으로 레이어 피처 맵 계산
        for l in range(self.L):
            FM_k_l = FM_k[l]
            # se_lfmd의 percent 인자의 디폴트 값이 50인데 이 다르게 하여 계산할 수도 있음
            lfmd_l = self.se_lfmd(FM_k_l, l)
            lfmds.append(lfmd_l)
        # 레이어 피처 맵마다 weight를 줌
        for l in range(self.L):
            fmd += self.W[l]*lfmds[l]

        return fmd
    
    def set_fmdc(self):
        # fmds는 오분류 테스트 데이터에 대한 fmd를 저장함
        fmds=[]

        # WFM을 부르기 위한 변수들을 선언함
        wtest=self.origin_names[2]; wtest_dir=self.wtest_dir; wtest_K=self.origin_K[wtest]
        WFMP_k=None; prev_WFMPI_k=None; cur_WFMPI_k=None;

        # k(=0)가 속한 WFMP을 가지고 옴
        k = 0
        prev_WFMPI_k = k // 1000
        with open(f'{wtest_dir}/{wtest}_{prev_WFMPI_k}.pickle', 'rb') as f:
            WFMP_k = pickle.load(f)

        # 오분류 데이터의 fmd의 최소값을 fmdc로 정함
        for k in range(wtest_K):
            # k번 째 데이터의 WFMPI, WFMPO 구함
            cur_WFMPI_k = k // 1000
            WFMPO_k = k % 1000

            # WFMP_k가 이미 있다면 가지고 오지 않고
            #             없다면 이전 WFMP를 지우고 현재 WFMP를 가지고 온다.

            # cur_WFMPI_k와 prev_WFMPI_k가 같다면
            if cur_WFMPI_k == prev_WFMPI_k:
                pass # 아무 작업 하지 않고

            # cur_WFMPI_k와 prev_WFMPI_k가 다를 경우
            else:
                # 이전 WFMP_k의 기억공간을 램에서 제거한 후
                del WFMP_k
                # cur_WFMPI_k를 현재 WFMP_k를 가지고 온다.
                with open(f'{wtest_dir}/{wtest}_{cur_WFMPI_k}.pickle', 'rb') as f:
                    WFMP_k = pickle.load(f)

            # prev_WFMPI_k를 cur_WFMPI_k로 초기화 
            prev_WFMPI_k = cur_WFMPI_k

            WFM_k = WFMP_k[WFMPO_k]

            fmds.append(self.fmd(WFM_k))
            
        fmds = np.array(fmds)
        
        self.fmdc = fmds.min()

    def eval(self):
        for eval_name in self.eval_names:
            # is_ts_fmds에 각 데이터마다 ts_fmd이라면 1, 아니라면 0이 저장됨
            is_ts_fmds = []
            fmds = []

            # EFM을 부르기 위한 변수들을 선언함
            eval_dir=f'{self.eval_dir}/{eval_name}'; eval_K=self.eval_K[eval_name]
            EFMP_k=None; prev_EFMPI_k=None; cur_EFMPI_k=None;

            # k(=0)가 속한 EFMP을 가지고 옴
            k = 0
            prev_EFMPI_k = k // 1000
            
            # {eval_name}_{prev_EFMPI_k}.pickle이 있는지 확인
            is_there_eval_name_prev_EFMPI_k_pickle = os.path.isfile(f'{eval_dir}/{eval_name}_{prev_EFMPI_k}.pickle')
            # {eval_name}_{prev_EFMPI_k}.pickle가 있다면 이 파일을 가지고 오고
            if is_there_eval_name_prev_EFMPI_k_pickle:
                with open(f'{eval_dir}/{eval_name}_{prev_EFMPI_k}.pickle', 'rb') as f:
                    EFMP_k = pickle.load(f)
            # {eval_name}_{prev_EFMPI_k}.pickle가 없다면
            # eval_{prev_EFMPI_k}.pickle 파일을 가지고 온다.
            else:
                with open(f'{eval_dir}/eval_{prev_EFMPI_k}.pickle', 'rb') as f:
                    EFMP_k = pickle.load(f)

            for k in range(1, eval_K):
                # k번 째 데이터의 EFMPI, EFMPO 구함
                cur_EFMPI_k = k // 1000
                EFMPO_k = k % 1000

                # EFMP_k가 이미 있다면 가지고 오지 않고
                #             없다면 이전 EFMP를 지우고 현재 EFMP를 가지고 온다.

                # cur_EFMPI_k와 prev_EFMPI_k가 같다면
                if cur_EFMPI_k == prev_EFMPI_k:
                    pass # 아무 작업 하지 않고

                # cur_EFMPI_k와 prev_EFMPI_k가 다를 경우
                else:
                    # 이전 EFMP_k의 기억공간을 램에서 제거한 후
                    del EFMP_k

                    # cur_EFMPI_k를 현재 EFMP_k를 가지고 온다.

                    # {eval_name}_{cur_EFMPI_k}.pickle이 있는지 확인
                    is_there_eval_name_cur_EFMPI_k_pickle = os.path.isfile(f'{eval_dir}/{eval_name}_{cur_EFMPI_k}.pickle')
                    # {eval_name}_{cur_EFMPI_k}.pickle가 있다면 이 파일을 가지고 오고
                    if is_there_eval_name_cur_EFMPI_k_pickle:
                        with open(f'{eval_dir}/{eval_name}_{cur_EFMPI_k}.pickle', 'rb') as f:
                            EFMP_k = pickle.load(f)
                    # {eval_name}_{cur_EFMPI_k}.pickle가 없다면
                    # eval_{cur_EFMPI_k}.pickle 파일을 가지고 온다.
                    else:
                        with open(f'{eval_dir}/eval_{cur_EFMPI_k}.pickle', 'rb') as f:
                            EFMP_k = pickle.load(f)

                # prev_EFMPI_k를 cur_EFMPI_k로 초기화 
                prev_EFMPI_k = cur_EFMPI_k

                EFM_k = EFMP_k[EFMPO_k]
                
                fmd = self.fmd(EFM_k)

                fmds.append(fmd)
                is_ts_fmds.append(fmd >= self.fmdc)
            
            fmds = np.array(fmds)
            is_ts_fmds = np.array(is_ts_fmds)

            # is_ts_fmds: 각 데이터가 ts_fmd인지 아닌지 알려주는 넘파이 배열
            np.save(f"{eval_dir}/{eval_name}_is_ts_fmds.npy",is_ts_fmds)
            # fmds: 각 데이터의 fmd를 저장하는 넘파이 배열
            np.save(f"{eval_dir}/{eval_name}_fmds.npy",fmds)
        
    def show_all(self):
        print('self.show_data_infos')
        self.show_data_infos()
        print('self.show_FM_means')
        self.show_FM_means()
        print('self.show_AMs_and_related')
        self.show_AMs_and_related()
        print('self.show_hyper_parameter')
        self.show_hyper_parameter()
        print('self.show_index_infos')
        '''
        사용하지 않음
        self.show_index_infos()
        print('self.show_layer_infos')
        '''
        self.show_layer_infos()
        print('self.show_fmdc')
        self.show_fmdc()
        print('self.show_dirs')
        self.show_dirs()
        print('self.show_eval_infos')
        self.show_eval_infos()
        
    def show_data_infos(self):
        print("self.origin_names"); print(self.origin_names)
        print("self.origin_K"); print(self.origin_K)
        print("self.eval_names"); print(self.eval_names)
        print("self.eval_K"); print(self.eval_K)
        print("self.L"); print(self.L)
        print("self.shape"); print(self.shape)

    def show_FM_means(self):
        print("self.TFM_mean"); self.show_square_FM(self.TFM_mean)
        print("self.RFM_mean"); self.show_square_FM(self.RFM_mean)
        print("self.WFM_mean"); self.show_square_FM(self.WFM_mean)

    def show_AMs_and_related(self):
        print("self.TAM"); self.show_square_FM(self.TAM)
        print("self.RAM"); self.show_square_FM(self.RAM)
        print("self.WAM"); self.show_square_FM(self.WAM)

        print("self.alpha_slice"); print(self.alpha_slice)
        print("self.alpha_min"); print(self.alpha_min)
        print("self.alpha"); print(self.alpha)
        print("self.alpha_max"); print(self.alpha_max)
        print("self.w_minus_r_max"); print(self.w_minus_r_max)

        print("self.DAM_select"); print(self.DAM_select)
        print("self.DAM"); self.show_square_FM(self.DAM)
        print("self.DAM_indexes"); print(self.DAM_indexes)

    def show_hyper_parameter(self):
        print("self.alpha_slice"); print(self.alpha_slice)
        print("self.DAM_select"); print(self.DAM_select)
        print("self.lfmd_select"); print(self.lfmd_select)
        print("self.W"); print(self.W)

    def show_index_infos(self):
        print("self.mid"); self.show_square_FM(self.mid)
        print("self.mean"); self.show_square_FM(self.mean)
        print("self.std"); self.show_square_FM(self.std)
        print("self.min"); self.show_square_FM(self.min)
        print("self.max"); self.show_square_FM(self.max)

    def show_layer_infos(self):
        print("self.lfmd_select"); print(self.lfmd_select)
        print("self.W"); print(self.W)

    def show_fmdc(self):
        print("self.fmdc"); print(self.fmdc)

    def show_dirs(self):
        print("self.root_dir"); print(self.root_dir)
        
        print("self.origin_dir"); print(self.origin_dir)
        print("self.train_dir"); print(self.train_dir)
        print("self.rtest_dir"); print(self.rtest_dir)
        print("self.wtest_dir"); print(self.wtest_dir)

        print("self.eval_dir"); print(self.eval_dir)

    def show_eval_infos(self):
        for eval_name in self.eval_names:
            print(f'In eval/{eval_name}')
            
            result_npy = np.load(f'{self.eval_dir}/{eval_name}/{eval_name}_result.npy')
            print(f'{eval_name}_result.npy'); print(result_npy)
            
            is_ts_fmds_npy = np.load(f'{self.eval_dir}/{eval_name}/{eval_name}_is_ts_fmds.npy')
            print(f'{eval_name}_is_ts_fmds.npy'); print(is_ts_fmds_npy)
            
            fmds_npy = np.load(f'{self.eval_dir}/{eval_name}/{eval_name}_fmds.npy')
            print(f'{eval_name}_fmds.npy'); print(fmds_npy)
    
    def show_square_FM(self, np_arr):
        # np_arr에 np_arr의 최소의 값부터 최대 값까지 그리는 넘파이 추가
        # 이 넘파이 배열을 그리는 이유는 최소 최대에 대한 시각적인 표현을 할 수 있을 뿐만 아니라
        # color bar로 인해 좁게 그려지는 넘파이 배열을 없앨 수 있다.
        # np_arr_min 찾기
        np_arr_min = np_arr[0].min()
        for i in range(1, len(np_arr)):
            if np_arr_min > np_arr[i].min():
                np_arr_min = np_arr[i].min()
        # np_arr_max 찾기
        np_arr_max = np_arr[0].max()
        for i in range(1, len(np_arr)):
            if np_arr_max > np_arr[i].max():
                np_arr_max = np_arr[i].max()
        # bool 타입이라면 마지막에 넘파이에 True, False만 넣고 즉, (T,T), (T,F), (F,T), (F,F)만 넣고
        if str(np_arr[0].dtype) == 'bool':
            np_arr.append(np.array([np_arr_min, np_arr_max]))
        # 그게 아니라면 마지막에 넘파이에 np_arr_slice로 잘린 연속적인 값들을 넣음.
        else:
            # np_arr_slice: np_arr_min 부터 np_arr_max 까지 그리는데 몇 번에 걸쳐서 그릴지 정하기
            np_arr_slice = 1000
            np_arr_interval = (np_arr_max - np_arr_min) / np_arr_slice
            # np_arr에 np_arr의 최소의 값부터 최대 값까지 그리는 넘파이 생성
            np_min_to_max = np.array([np_arr_min + i*np_arr_interval for i in range(np_arr_slice+1)])
            np_arr.append(np_min_to_max)

        # 레이어 개수 만큼 레이어 원소 개수 계산
        element_count=[]
        for ith in range(len(np_arr)):
            ith_element_count = 1
            for ith_shape_ele in np_arr[ith].shape:
                ith_element_count *= ith_shape_ele
            
            element_count.append(ith_element_count)
        # 레이어 원소 개수로 정방 이차 배열의 한 변의 길이 구함
        square_FM_side=[]
        for ith in range(len(np_arr)):
            square_FM_side.append(math.ceil(math.sqrt((element_count[ith]))))
        # square_FM_side_min으로 그래프 크기를 정함
        square_FM_side_min = np.array(square_FM_side).min()
        square_FM_side_max = np.array(square_FM_side).max()

        # 레이어 피처 맵을 평탄화함.
        np_arr_flatten=[]
        for ith in range(len(np_arr)):
            np_arr_flatten.append(np_arr[ith].flatten())

        # x,y로 np_arr를 그리기 위한 이차 정방 배열 좌표를 만듦
        x=[];y=[]
        for ith in range(len(np_arr)):
            x_ith=[]; y_ith=[]
            for y_ in range(square_FM_side[ith]):
                for x_ in range(square_FM_side[ith]):
                    x_ith.append(x_)
                    y_ith.append(y_)
            # x_ith, y_ith를 np_arr[ith] 개수 만큼 자름
            x_ith = x_ith[:element_count[ith]]; y_ith = y_ith[:element_count[ith]]
            # x_ith을 x에 넣고 y_ith을 y에 넣음
            x.append(x_ith); y.append(y_ith)

        # plt의 subplot의 크기 지정
        plt_column = 15
        plt_row = (len(np_arr)-1 // plt_column) + 1

        # 넘파이 배열을 5줄 씩 그리기
        plt.figure(figsize=(3*20, 8*20))
        for i in range(len(np_arr)):
            plt.subplot(plt_row,plt_column,i+1)
            plt.scatter(x=x[i], y=y[i], c=np_arr_flatten[i], cmap='jet')
        plt.colorbar()

    def save(self, model_name):
        # 인자로 지정된 경로와 이름으로 파일 저장
        with open(f"./instances/{model_name}.pickle", "wb") as f:
            pickle.dump(self, f, pickle.HIGHEST_PROTOCOL)

    def load(self, model_name):
        # 인자로 지정된 경로와 이름으로 파일 불러오기
        with open(f"./instances/{model_name}.pickle", "rb" ) as f:
            return copy.deepcopy(pickle.load(f))

# %%
fmd1 = FMD("/Volumes/My Passport_ssd_sg3/data_sets/fmnist/shirts")
# fmd1.create_practice()
fmd1.fit()
# Out:
# Time elapsed:  0:00:00.026475
# Time elapsed:  0:00:00.029912
# Time elapsed:  0:00:00.031963
# Time elapsed:  0:00:00.031349
# Time elapsed:  0:00:00.030550
# Time elapsed:  0:00:00.029775
# Time elapsed:  0:00:00.028371
# Time elapsed:  0:00:00.031021
# Time elapsed:  0:00:00.035522
# Time elapsed:  0:00:00.042761
# Time elapsed:  0:00:00.033997
# Time elapsed:  0:00:00.031162
# Time elapsed:  0:00:00.029635
# Time elapsed:  0:00:00.033259
# Time elapsed:  0:00:00.040630
# Time elapsed:  0:00:00.034061
# Time elapsed:  0:00:00.031175
# Time elapsed:  0:00:00.037879
# Time elapsed:  0:00:00.036256
# Time elapsed:  0:00:00.035947
# Time elapsed:  0:00:00.050924
# Time elapsed:  0:00:00.042823
# Time elapsed:  0:00:00.038004
# Time elapsed:  0:00:00.035909
# Time elapsed:  0:00:00.033406
# Time elapsed:  0:00:00.041505
# Time elapsed:  0:00:00.033520
# Time elapsed:  0:00:00.032190
# Time elapsed:  0:00:00.028951
# Time elapsed:  0:00:00.029721
# Time elapsed:  0:00:00.029644
# Time elapsed:  0:00:00.039145
# Time elapsed:  0:00:00.041377
# Time elapsed:  0:00:00.032315
# Time elapsed:  0:00:00.031432
# Time elapsed:  0:00:00.030891
# Time elapsed:  0:00:00.031551
# Time elapsed:  0:00:00.029581
# Time elapsed:  0:00:00.041604
# Time elapsed:  0:00:00.037739
# Time elapsed:  0:00:00.031134
# Time elapsed:  0:00:00.028989
# Time elapsed:  0:00:00.032690
# Time elapsed:  0:00:00.030973
# Time elapsed:  0:00:00.033443
# Time elapsed:  0:00:00.040453
# Time elapsed:  0:00:00.038199
# Time elapsed:  0:00:00.037374
# Time elapsed:  0:00:00.030747
# Time elapsed:  0:00:00.032240
# Time elapsed:  0:00:00.033117
# Time elapsed:  0:00:00.033744
# Time elapsed:  0:00:00.040438
# Time elapsed:  0:00:00.036015
# Time elapsed:  0:00:00.031965
# Time elapsed:  0:00:00.030269
# Time elapsed:  0:00:00.028623
# Time elapsed:  0:00:00.028756
# Time elapsed:  0:00:00.039216
# Time elapsed:  0:00:00.040544
# Time elapsed:  0:00:00.034534
# Time elapsed:  0:00:00.031076
# Time elapsed:  0:00:00.037031
# Time elapsed:  0:00:00.032216
# Time elapsed:  0:00:00.037035
# Time elapsed:  0:00:00.041292
# Time elapsed:  0:00:00.037307
# Time elapsed:  0:00:00.031810
# Time elapsed:  0:00:00.034050
# Time elapsed:  0:00:00.038497
# Time elapsed:  0:00:00.033591
# Time elapsed:  0:00:00.041717
# Time elapsed:  0:00:00.035911
# Time elapsed:  0:00:00.034266
# Time elapsed:  0:00:00.034148
# Time elapsed:  0:00:00.029428
# Time elapsed:  0:00:00.034189
# Time elapsed:  0:00:00.042893
# Time elapsed:  0:00:00.037082
# Time elapsed:  0:00:00.032835
# Time elapsed:  0:00:00.030825
# Time elapsed:  0:00:00.038237
# Time elapsed:  0:00:00.040289
# Time elapsed:  0:00:00.053975
# Time elapsed:  0:00:00.061862
# Time elapsed:  0:00:00.054554
# Time elapsed:  0:00:00.066748
# Time elapsed:  0:00:00.076015
# Time elapsed:  0:00:00.070009
# Time elapsed:  0:00:00.067154
# Time elapsed:  0:00:00.057481
# Time elapsed:  0:00:00.057464
# Time elapsed:  0:00:00.070055
# Time elapsed:  0:00:00.056005
# Time elapsed:  0:00:00.063148
# Time elapsed:  0:00:00.056227
# Time elapsed:  0:00:00.058206
# Time elapsed:  0:00:00.047552
# Time elapsed:  0:00:00.048554
# Time elapsed:  0:00:00.045627
# Time elapsed:  0:00:00.034412
# Time elapsed:  0:00:00.033129
# Time elapsed:  0:00:00.043042
# Time elapsed:  0:00:00.038981
# Time elapsed:  0:00:00.034528
# Time elapsed:  0:00:00.030473
# Time elapsed:  0:00:00.033094
# Time elapsed:  0:00:00.035771
# Time elapsed:  0:00:00.042618
# Time elapsed:  0:00:00.037749
# Time elapsed:  0:00:00.032694
# Time elapsed:  0:00:00.031974
# Time elapsed:  0:00:00.034100
# Time elapsed:  0:00:00.038002
# Time elapsed:  0:00:00.046917
# Time elapsed:  0:00:00.037926
# Time elapsed:  0:00:00.034706
# Time elapsed:  0:00:00.031024
# Time elapsed:  0:00:00.030574
# Time elapsed:  0:00:00.038477
# Time elapsed:  0:00:00.047294
# Time elapsed:  0:00:00.038213
# Time elapsed:  0:00:00.033422
# Time elapsed:  0:00:00.033808
# Time elapsed:  0:00:00.051362
# Time elapsed:  0:00:00.058261
# Time elapsed:  0:00:00.055747
# Time elapsed:  0:00:00.061184
# Time elapsed:  0:00:00.060307
# Time elapsed:  0:00:00.048401
# Time elapsed:  0:00:00.048123
# Time elapsed:  0:00:00.059669
# Time elapsed:  0:00:00.055222
# Time elapsed:  0:00:00.042701
# Time elapsed:  0:00:00.033474
# Time elapsed:  0:00:00.034116
# Time elapsed:  0:00:00.035942
# Time elapsed:  0:00:00.039323
# Time elapsed:  0:00:00.035581
# Time elapsed:  0:00:00.032318
# Time elapsed:  0:00:00.032621
# Time elapsed:  0:00:00.030916
# Time elapsed:  0:00:00.035012
# Time elapsed:  0:00:00.039109
# Time elapsed:  0:00:00.039012
# Time elapsed:  0:00:00.034362
# Time elapsed:  0:00:00.033911
# Time elapsed:  0:00:00.032981
# Time elapsed:  0:00:00.034143
# Time elapsed:  0:00:00.040552
# Time elapsed:  0:00:00.034245
# Time elapsed:  0:00:00.032772
# Time elapsed:  0:00:00.030723
# Time elapsed:  0:00:00.032371
# Time elapsed:  0:00:00.042307
# Time elapsed:  0:00:00.060517
# Time elapsed:  0:00:00.058674
# Time elapsed:  0:00:00.056052
# Time elapsed:  0:00:00.065302
# Time elapsed:  0:00:00.054122
# Time elapsed:  0:00:00.054648
# Time elapsed:  0:00:00.041727
# Time elapsed:  0:00:00.038288
# Time elapsed:  0:00:00.035560
# Time elapsed:  0:00:00.043295
# Time elapsed:  0:00:00.033907
# Time elapsed:  0:00:00.034490
# Time elapsed:  0:00:00.033200
# Time elapsed:  0:00:00.039351
# Time elapsed:  0:00:00.046928
# Time elapsed:  0:00:00.045414
# Time elapsed:  0:00:00.035898
# Time elapsed:  0:00:00.033733
# Time elapsed:  0:00:00.032694
# Time elapsed:  0:00:00.033995
# Time elapsed:  0:00:00.042826
# Time elapsed:  0:00:00.054309

# %%
fmd1.show_fmdc()
# Out:
# self.fmdc
# 4199.252005996141

# %%
fmd1.eval()
# Out:
# Time elapsed:  0:00:00.041737
# Time elapsed:  0:00:00.036721
# Time elapsed:  0:00:00.039137
# Time elapsed:  0:00:00.052843
# Time elapsed:  0:00:00.058042
# Time elapsed:  0:00:00.063501
# Time elapsed:  0:00:00.066830
# Time elapsed:  0:00:00.056865
# Time elapsed:  0:00:00.046237
# Time elapsed:  0:00:00.046579
# Time elapsed:  0:00:00.038204
# Time elapsed:  0:00:00.034391
# Time elapsed:  0:00:00.030662
# Time elapsed:  0:00:00.030828
# Time elapsed:  0:00:00.032473
# Time elapsed:  0:00:00.036550
# Time elapsed:  0:00:00.043648
# Time elapsed:  0:00:00.038003
# Time elapsed:  0:00:00.052761
# Time elapsed:  0:00:00.063817
# Time elapsed:  0:00:00.058488
# Time elapsed:  0:00:00.060164
# Time elapsed:  0:00:00.057785
# Time elapsed:  0:00:00.058953
# Time elapsed:  0:00:00.058213
# Time elapsed:  0:00:00.054243
# Time elapsed:  0:00:00.053673
# Time elapsed:  0:00:00.059868
# Time elapsed:  0:00:00.062048
# Time elapsed:  0:00:00.056492
# Time elapsed:  0:00:00.057182
# Time elapsed:  0:00:00.068218
# Time elapsed:  0:00:00.061863
# Time elapsed:  0:00:00.060482
# Time elapsed:  0:00:00.046847
# Time elapsed:  0:00:00.053062
# Time elapsed:  0:00:00.052544
# Time elapsed:  0:00:00.050989
# Time elapsed:  0:00:00.054781
# Time elapsed:  0:00:00.056477
# Time elapsed:  0:00:00.054487
# Time elapsed:  0:00:00.038198
# Time elapsed:  0:00:00.038239
# Time elapsed:  0:00:00.036183
# Time elapsed:  0:00:00.038161
# Time elapsed:  0:00:00.042118
# Time elapsed:  0:00:00.042750
# Time elapsed:  0:00:00.039248
# Time elapsed:  0:00:00.041499
# Time elapsed:  0:00:00.052540
# Time elapsed:  0:00:00.049347
# Time elapsed:  0:00:00.037107
# Time elapsed:  0:00:00.032097
# Time elapsed:  0:00:00.030887
# Time elapsed:  0:00:00.032982
# Time elapsed:  0:00:00.038706
# Time elapsed:  0:00:00.051034
# Time elapsed:  0:00:00.060064
# Time elapsed:  0:00:00.058555
# Time elapsed:  0:00:00.063567
# Time elapsed:  0:00:00.058380
# Time elapsed:  0:00:00.053931
# Time elapsed:  0:00:00.038085
# Time elapsed:  0:00:00.036761
# Time elapsed:  0:00:00.047589
# Time elapsed:  0:00:00.045581
# Time elapsed:  0:00:00.041047
# Time elapsed:  0:00:00.036483
# Time elapsed:  0:00:00.041389
# Time elapsed:  0:00:00.050797
# Time elapsed:  0:00:00.048434
# Time elapsed:  0:00:00.038665
# Time elapsed:  0:00:00.035710
# Time elapsed:  0:00:00.032208
# Time elapsed:  0:00:00.032007
# Time elapsed:  0:00:00.036329
# Time elapsed:  0:00:00.042653
# Time elapsed:  0:00:00.059492
# Time elapsed:  0:00:00.046869
# Time elapsed:  0:00:00.037583
# Time elapsed:  0:00:00.048518
# Time elapsed:  0:00:00.039067
# Time elapsed:  0:00:00.033346
# Time elapsed:  0:00:00.038939
# Time elapsed:  0:00:00.046097
# Time elapsed:  0:00:00.043981
# Time elapsed:  0:00:00.052013
# Time elapsed:  0:00:00.049317
# Time elapsed:  0:00:00.056463
# Time elapsed:  0:00:00.071632
# Time elapsed:  0:00:00.073357
# Time elapsed:  0:00:00.066152
# Time elapsed:  0:00:00.052385
# Time elapsed:  0:00:00.052745
# Time elapsed:  0:00:00.038516
# Time elapsed:  0:00:00.037642
# Time elapsed:  0:00:00.054129
# Time elapsed:  0:00:00.051430
# Time elapsed:  0:00:00.049829
# Time elapsed:  0:00:00.039571
# Time elapsed:  0:00:00.032060
# Time elapsed:  0:00:00.030406
# Time elapsed:  0:00:00.030915
# Time elapsed:  0:00:00.037343
# Time elapsed:  0:00:00.047170
# Time elapsed:  0:00:00.049418
# Time elapsed:  0:00:00.049463
# Time elapsed:  0:00:00.056769
# Time elapsed:  0:00:00.052279
# Time elapsed:  0:00:00.063364
# Time elapsed:  0:00:00.053550
# Time elapsed:  0:00:00.061347
# Time elapsed:  0:00:00.059110
# Time elapsed:  0:00:00.061811
# Time elapsed:  0:00:00.060934
# Time elapsed:  0:00:00.066721
# Time elapsed:  0:00:00.072787
# Time elapsed:  0:00:00.054124
# Time elapsed:  0:00:00.057189
# Time elapsed:  0:00:00.060729
# Time elapsed:  0:00:00.068051
# Time elapsed:  0:00:00.060401
# Time elapsed:  0:00:00.062214
# Time elapsed:  0:00:00.060959
# Time elapsed:  0:00:00.063973
# Time elapsed:  0:00:00.048708
# Time elapsed:  0:00:00.057447
# Time elapsed:  0:00:00.058762
# Time elapsed:  0:00:00.061174
# Time elapsed:  0:00:00.059519
# Time elapsed:  0:00:00.061730
# Time elapsed:  0:00:00.057047
# Time elapsed:  0:00:00.046283
# Time elapsed:  0:00:00.048674
# Time elapsed:  0:00:00.054476
# Time elapsed:  0:00:00.051652
# Time elapsed:  0:00:00.058178
# Time elapsed:  0:00:00.056987
# Time elapsed:  0:00:00.061364
# Time elapsed:  0:00:00.061548
# Time elapsed:  0:00:00.059736
# Time elapsed:  0:00:00.050413
# Time elapsed:  0:00:00.059337
# Time elapsed:  0:00:00.060953
# Time elapsed:  0:00:00.051040
# Time elapsed:  0:00:00.046987
# Time elapsed:  0:00:00.042406
# Time elapsed:  0:00:00.045325
# Time elapsed:  0:00:00.051174
# Time elapsed:  0:00:00.060385
# Time elapsed:  0:00:00.054851
# Time elapsed:  0:00:00.068260
# Time elapsed:  0:00:00.066214
# Time elapsed:  0:00:00.063821
# Time elapsed:  0:00:00.053957
# Time elapsed:  0:00:00.051214
# Time elapsed:  0:00:00.056136
# Time elapsed:  0:00:00.056517
# Time elapsed:  0:00:00.066528
# Time elapsed:  0:00:00.059458
# Time elapsed:  0:00:00.058400
# Time elapsed:  0:00:00.066522
# Time elapsed:  0:00:00.062659
# Time elapsed:  0:00:00.061671
# Time elapsed:  0:00:00.061183
# Time elapsed:  0:00:00.057323
# Time elapsed:  0:00:00.054369
# Time elapsed:  0:00:00.060524
# Time elapsed:  0:00:00.056080
# Time elapsed:  0:00:00.048189
# Time elapsed:  0:00:00.046614
# Time elapsed:  0:00:00.046430
# Time elapsed:  0:00:00.054400
# Time elapsed:  0:00:00.072786
# Time elapsed:  0:00:00.078179
# Time elapsed:  0:00:00.063019
# Time elapsed:  0:00:00.059857
# Time elapsed:  0:00:00.057991
# Time elapsed:  0:00:00.062888
# Time elapsed:  0:00:00.069936
# Time elapsed:  0:00:00.059229
# Time elapsed:  0:00:00.075122
# Time elapsed:  0:00:00.069300
# Time elapsed:  0:00:00.061561
# Time elapsed:  0:00:00.067744
# Time elapsed:  0:00:00.063987
# Time elapsed:  0:00:00.062202
# Time elapsed:  0:00:00.057751
# Time elapsed:  0:00:00.056948
# Time elapsed:  0:00:00.061520
# Time elapsed:  0:00:00.056594
# Time elapsed:  0:00:00.055398
# Time elapsed:  0:00:00.057496
# Time elapsed:  0:00:00.060753
# Time elapsed:  0:00:00.051995
# Time elapsed:  0:00:00.057341
# Time elapsed:  0:00:00.059848
# Time elapsed:  0:00:00.061015
# Time elapsed:  0:00:00.055446
# Time elapsed:  0:00:00.059051
# Time elapsed:  0:00:00.055128
# Time elapsed:  0:00:00.059343
# Time elapsed:  0:00:00.061117
# Time elapsed:  0:00:00.059636
# Time elapsed:  0:00:00.058585
# Time elapsed:  0:00:00.061720
# Time elapsed:  0:00:00.061954
# Time elapsed:  0:00:00.068412
# Time elapsed:  0:00:00.068114
# Time elapsed:  0:00:00.070207
# Time elapsed:  0:00:00.069400
# Time elapsed:  0:00:00.063417
# Time elapsed:  0:00:00.065265
# Time elapsed:  0:00:00.062139
# Time elapsed:  0:00:00.065777
# Time elapsed:  0:00:00.064291
# Time elapsed:  0:00:00.057079
# Time elapsed:  0:00:00.070278
# Time elapsed:  0:00:00.064598
# Time elapsed:  0:00:00.061975
# Time elapsed:  0:00:00.070051
# Time elapsed:  0:00:00.062056
# Time elapsed:  0:00:00.061838
# Time elapsed:  0:00:00.065479
# Time elapsed:  0:00:00.067762
# Time elapsed:  0:00:00.066828
# Time elapsed:  0:00:00.074996
# Time elapsed:  0:00:00.063031
# Time elapsed:  0:00:00.050995
# Time elapsed:  0:00:00.036087
# Time elapsed:  0:00:00.031589
# Time elapsed:  0:00:00.037068
# Time elapsed:  0:00:00.049120
# Time elapsed:  0:00:00.039777
# Time elapsed:  0:00:00.041537
# Time elapsed:  0:00:00.033690
# Time elapsed:  0:00:00.047116
# Time elapsed:  0:00:00.079819
# Time elapsed:  0:00:00.081911
# Time elapsed:  0:00:00.058370
# Time elapsed:  0:00:00.051394
# Time elapsed:  0:00:00.044084
# Time elapsed:  0:00:00.039967
# Time elapsed:  0:00:00.044703
# Time elapsed:  0:00:00.054487
# Time elapsed:  0:00:00.051329
# Time elapsed:  0:00:00.040946
# Time elapsed:  0:00:00.036128
# Time elapsed:  0:00:00.043667
# Time elapsed:  0:00:00.047074
# Time elapsed:  0:00:00.040573
# Time elapsed:  0:00:00.058203
# Time elapsed:  0:00:00.060162
# Time elapsed:  0:00:00.069104
# Time elapsed:  0:00:00.061196
# Time elapsed:  0:00:00.047209
# Time elapsed:  0:00:00.045972
# Time elapsed:  0:00:00.048454
# Time elapsed:  0:00:00.038630
# Time elapsed:  0:00:00.035038
# Time elapsed:  0:00:00.034739
# Time elapsed:  0:00:00.034652
# Time elapsed:  0:00:00.042685
# Time elapsed:  0:00:00.045852
# Time elapsed:  0:00:00.038906
# Time elapsed:  0:00:00.037219
# Time elapsed:  0:00:00.032912
# Time elapsed:  0:00:00.031555
# Time elapsed:  0:00:00.037564
# Time elapsed:  0:00:00.052259
# Time elapsed:  0:00:00.055586
# Time elapsed:  0:00:00.061728
# Time elapsed:  0:00:00.064545
# Time elapsed:  0:00:00.067320
# Time elapsed:  0:00:00.054429
# Time elapsed:  0:00:00.055058
# Time elapsed:  0:00:00.048906
# Time elapsed:  0:00:00.056674
# Time elapsed:  0:00:00.054070
# Time elapsed:  0:00:00.041865
# Time elapsed:  0:00:00.038067
# Time elapsed:  0:00:00.041922
# Time elapsed:  0:00:00.035103
# Time elapsed:  0:00:00.037236
# Time elapsed:  0:00:00.035050
# Time elapsed:  0:00:00.034072
# Time elapsed:  0:00:00.034719
# Time elapsed:  0:00:00.034878
# Time elapsed:  0:00:00.032678
# Time elapsed:  0:00:00.031782
# Time elapsed:  0:00:00.033290
# Time elapsed:  0:00:00.033912
# Time elapsed:  0:00:00.047835
# Time elapsed:  0:00:00.062678
# Time elapsed:  0:00:00.060836
# Time elapsed:  0:00:00.065710
# Time elapsed:  0:00:00.056192
# Time elapsed:  0:00:00.042154
# Time elapsed:  0:00:00.038267
# Time elapsed:  0:00:00.048411
# Time elapsed:  0:00:00.052938
# Time elapsed:  0:00:00.044320
# Time elapsed:  0:00:00.039850
# Time elapsed:  0:00:00.036201
# Time elapsed:  0:00:00.033303
# Time elapsed:  0:00:00.034666
# Time elapsed:  0:00:00.047737
# Time elapsed:  0:00:00.049973
# Time elapsed:  0:00:00.039887
# Time elapsed:  0:00:00.043528
# Time elapsed:  0:00:00.038878
# Time elapsed:  0:00:00.036252
# Time elapsed:  0:00:00.037745
# Time elapsed:  0:00:00.031871
# Time elapsed:  0:00:00.034379
# Time elapsed:  0:00:00.031678
# Time elapsed:  0:00:00.037371
# Time elapsed:  0:00:00.053637
# Time elapsed:  0:00:00.054606
# Time elapsed:  0:00:00.051005
# Time elapsed:  0:00:00.057563
# Time elapsed:  0:00:00.065763
# Time elapsed:  0:00:00.062564
# Time elapsed:  0:00:00.059474
# Time elapsed:  0:00:00.071205
# Time elapsed:  0:00:00.068701
# Time elapsed:  0:00:00.060613
# Time elapsed:  0:00:00.066980
# Time elapsed:  0:00:00.061459
# Time elapsed:  0:00:00.061613
# Time elapsed:  0:00:00.060825
# Time elapsed:  0:00:00.064559
# Time elapsed:  0:00:00.071949
# Time elapsed:  0:00:00.051152
# Time elapsed:  0:00:00.039695
# Time elapsed:  0:00:00.056437
# Time elapsed:  0:00:00.050561
# Time elapsed:  0:00:00.062812
# Time elapsed:  0:00:00.059593
# Time elapsed:  0:00:00.066140
# Time elapsed:  0:00:00.061920
# Time elapsed:  0:00:00.063249
# Time elapsed:  0:00:00.057891
# Time elapsed:  0:00:00.063677
# Time elapsed:  0:00:00.062698
# Time elapsed:  0:00:00.058445
# Time elapsed:  0:00:00.048097
# Time elapsed:  0:00:00.058657
# Time elapsed:  0:00:00.060785
# Time elapsed:  0:00:00.058528
# Time elapsed:  0:00:00.054609
# Time elapsed:  0:00:00.066500
# Time elapsed:  0:00:00.058954
# Time elapsed:  0:00:00.067133
# Time elapsed:  0:00:00.074460
# Time elapsed:  0:00:00.062316
# Time elapsed:  0:00:00.058546
# Time elapsed:  0:00:00.053865
# Time elapsed:  0:00:00.053828
# Time elapsed:  0:00:00.048755
# Time elapsed:  0:00:00.039725
# Time elapsed:  0:00:00.038488
# Time elapsed:  0:00:00.040275
# Time elapsed:  0:00:00.057463
# Time elapsed:  0:00:00.060373
# Time elapsed:  0:00:00.067071
# Time elapsed:  0:00:00.064347
# Time elapsed:  0:00:00.068894
# Time elapsed:  0:00:00.062056
# Time elapsed:  0:00:00.061999
# Time elapsed:  0:00:00.066775
# Time elapsed:  0:00:00.062256
# Time elapsed:  0:00:00.049074
# Time elapsed:  0:00:00.051840
# Time elapsed:  0:00:00.042527
# Time elapsed:  0:00:00.036317
# Time elapsed:  0:00:00.033964
# Time elapsed:  0:00:00.034427
# Time elapsed:  0:00:00.034857
# Time elapsed:  0:00:00.038221
# Time elapsed:  0:00:00.040703
# Time elapsed:  0:00:00.045203
# Time elapsed:  0:00:00.042732
# Time elapsed:  0:00:00.046135
# Time elapsed:  0:00:00.054510
# Time elapsed:  0:00:00.045859
# Time elapsed:  0:00:00.048502
# Time elapsed:  0:00:00.043593
# Time elapsed:  0:00:00.040800
# Time elapsed:  0:00:00.052943
# Time elapsed:  0:00:00.058200
# Time elapsed:  0:00:00.065787
# Time elapsed:  0:00:00.043254
# Time elapsed:  0:00:00.047434
# Time elapsed:  0:00:00.048588
# Time elapsed:  0:00:00.044982
# Time elapsed:  0:00:00.043830
# Time elapsed:  0:00:00.044177
# Time elapsed:  0:00:00.058613
# Time elapsed:  0:00:00.056304
# Time elapsed:  0:00:00.059712
# Time elapsed:  0:00:00.061586
# Time elapsed:  0:00:00.067193
# Time elapsed:  0:00:00.052587
# Time elapsed:  0:00:00.044754
# Time elapsed:  0:00:00.043497
# Time elapsed:  0:00:00.052533
# Time elapsed:  0:00:00.047726
# Time elapsed:  0:00:00.042989
# Time elapsed:  0:00:00.038165
# Time elapsed:  0:00:00.035907
# Time elapsed:  0:00:00.042820
# Time elapsed:  0:00:00.062747
# Time elapsed:  0:00:00.066645
# Time elapsed:  0:00:00.068812
# Time elapsed:  0:00:00.076376
# Time elapsed:  0:00:00.052507
# Time elapsed:  0:00:00.038703
# Time elapsed:  0:00:00.039799
# Time elapsed:  0:00:00.045900
# Time elapsed:  0:00:00.054337
# Time elapsed:  0:00:00.041210
# Time elapsed:  0:00:00.037057
# Time elapsed:  0:00:00.048024
# Time elapsed:  0:00:00.047326
# Time elapsed:  0:00:00.036850
# Time elapsed:  0:00:00.034914
# Time elapsed:  0:00:00.032402
# Time elapsed:  0:00:00.031186
# Time elapsed:  0:00:00.038932
# Time elapsed:  0:00:00.043668
# Time elapsed:  0:00:00.037759
# Time elapsed:  0:00:00.038468
# Time elapsed:  0:00:00.044019
# Time elapsed:  0:00:00.049962
# Time elapsed:  0:00:00.046682
# Time elapsed:  0:00:00.043365
# Time elapsed:  0:00:00.039867
# Time elapsed:  0:00:00.034139
# Time elapsed:  0:00:00.035677
# Time elapsed:  0:00:00.043112
# Time elapsed:  0:00:00.059240
# Time elapsed:  0:00:00.044439
# Time elapsed:  0:00:00.035394
# Time elapsed:  0:00:00.044799
# Time elapsed:  0:00:00.045379
# Time elapsed:  0:00:00.035810
# Time elapsed:  0:00:00.035716
# Time elapsed:  0:00:00.035397
# Time elapsed:  0:00:00.041809
# Time elapsed:  0:00:00.059440
# Time elapsed:  0:00:00.061484
# Time elapsed:  0:00:00.058813
# Time elapsed:  0:00:00.056675
# Time elapsed:  0:00:00.061795
# Time elapsed:  0:00:00.065366
# Time elapsed:  0:00:00.068097
# Time elapsed:  0:00:00.074526
# Time elapsed:  0:00:00.078716
# Time elapsed:  0:00:00.064718
# Time elapsed:  0:00:00.060836
# Time elapsed:  0:00:00.053820
# Time elapsed:  0:00:00.041395
# Time elapsed:  0:00:00.036882
# Time elapsed:  0:00:00.035177
# Time elapsed:  0:00:00.038179
# Time elapsed:  0:00:00.041939
# Time elapsed:  0:00:00.043801
# Time elapsed:  0:00:00.037491
# Time elapsed:  0:00:00.030410
# Time elapsed:  0:00:00.034773
# Time elapsed:  0:00:00.038054
# Time elapsed:  0:00:00.047265
# Time elapsed:  0:00:00.049377
# Time elapsed:  0:00:00.070184
# Time elapsed:  0:00:00.068520
# Time elapsed:  0:00:00.062948
# Time elapsed:  0:00:00.049048
# Time elapsed:  0:00:00.045898
# Time elapsed:  0:00:00.045730
# Time elapsed:  0:00:00.039750
# Time elapsed:  0:00:00.034463
# Time elapsed:  0:00:00.033929
# Time elapsed:  0:00:00.034828
# Time elapsed:  0:00:00.038638
# Time elapsed:  0:00:00.047743
# Time elapsed:  0:00:00.040840
# Time elapsed:  0:00:00.036094
# Time elapsed:  0:00:00.056536
# Time elapsed:  0:00:00.068014
# Time elapsed:  0:00:00.066968
# Time elapsed:  0:00:00.048151
# Time elapsed:  0:00:00.039569
# Time elapsed:  0:00:00.036481
# Time elapsed:  0:00:00.040971
# Time elapsed:  0:00:00.043323
# Time elapsed:  0:00:00.041045
# Time elapsed:  0:00:00.039208
# Time elapsed:  0:00:00.034865
# Time elapsed:  0:00:00.035624
# Time elapsed:  0:00:00.055267
# Time elapsed:  0:00:00.055058
# Time elapsed:  0:00:00.050791
# Time elapsed:  0:00:00.060197
# Time elapsed:  0:00:00.069090
# Time elapsed:  0:00:00.058724
# Time elapsed:  0:00:00.056665
# Time elapsed:  0:00:00.064076
# Time elapsed:  0:00:00.059656
# Time elapsed:  0:00:00.059869
# Time elapsed:  0:00:00.047187
# Time elapsed:  0:00:00.035940
# Time elapsed:  0:00:00.035709
# Time elapsed:  0:00:00.037580
# Time elapsed:  0:00:00.044266
# Time elapsed:  0:00:00.042649
# Time elapsed:  0:00:00.037807
# Time elapsed:  0:00:00.035531
# Time elapsed:  0:00:00.033540
# Time elapsed:  0:00:00.039790
# Time elapsed:  0:00:00.057783
# Time elapsed:  0:00:00.043358
# Time elapsed:  0:00:00.035026
# Time elapsed:  0:00:00.036762
# Time elapsed:  0:00:00.044336
# Time elapsed:  0:00:00.046000
# Time elapsed:  0:00:00.040581
# Time elapsed:  0:00:00.033699
# Time elapsed:  0:00:00.035346
# Time elapsed:  0:00:00.035408
# Time elapsed:  0:00:00.040310
# Time elapsed:  0:00:00.049931
# Time elapsed:  0:00:00.044170
# Time elapsed:  0:00:00.049089
# Time elapsed:  0:00:00.065102
# Time elapsed:  0:00:00.058023
# Time elapsed:  0:00:00.054237
# Time elapsed:  0:00:00.038776
# Time elapsed:  0:00:00.047660
# Time elapsed:  0:00:00.068799
# Time elapsed:  0:00:00.076880
# Time elapsed:  0:00:00.070467
# Time elapsed:  0:00:00.071388
# Time elapsed:  0:00:00.068974
# Time elapsed:  0:00:00.076748
# Time elapsed:  0:00:00.078307
# Time elapsed:  0:00:00.070196
# Time elapsed:  0:00:00.062495
# Time elapsed:  0:00:00.078688
# Time elapsed:  0:00:00.070463
# Time elapsed:  0:00:00.080877
# Time elapsed:  0:00:00.071510
# Time elapsed:  0:00:00.059531
# Time elapsed:  0:00:00.045833
# Time elapsed:  0:00:00.051100
# Time elapsed:  0:00:00.054336
# Time elapsed:  0:00:00.064346
# Time elapsed:  0:00:00.056539
# Time elapsed:  0:00:00.062702
# Time elapsed:  0:00:00.052240
# Time elapsed:  0:00:00.040122
# Time elapsed:  0:00:00.036516
# Time elapsed:  0:00:00.041955
# Time elapsed:  0:00:00.039317
# Time elapsed:  0:00:00.038801
# Time elapsed:  0:00:00.038783
# Time elapsed:  0:00:00.035918
# Time elapsed:  0:00:00.031596
# Time elapsed:  0:00:00.033471
# Time elapsed:  0:00:00.037511
# Time elapsed:  0:00:00.040066
# Time elapsed:  0:00:00.034493
# Time elapsed:  0:00:00.037873
# Time elapsed:  0:00:00.050320
# Time elapsed:  0:00:00.058946
# Time elapsed:  0:00:00.057971
# Time elapsed:  0:00:00.056627
# Time elapsed:  0:00:00.044567
# Time elapsed:  0:00:00.040808
# Time elapsed:  0:00:00.039137
# Time elapsed:  0:00:00.038074
# Time elapsed:  0:00:00.035022
# Time elapsed:  0:00:00.035134
# Time elapsed:  0:00:00.034268
# Time elapsed:  0:00:00.039351
# Time elapsed:  0:00:00.037394
# Time elapsed:  0:00:00.038745
# Time elapsed:  0:00:00.033181
# Time elapsed:  0:00:00.032715
# Time elapsed:  0:00:00.034277
# Time elapsed:  0:00:00.039157
# Time elapsed:  0:00:00.047870
# Time elapsed:  0:00:00.038628
# Time elapsed:  0:00:00.037581
# Time elapsed:  0:00:00.038870
# Time elapsed:  0:00:00.038265
# Time elapsed:  0:00:00.045220
# Time elapsed:  0:00:00.039518
# Time elapsed:  0:00:00.038759
# Time elapsed:  0:00:00.037617
# Time elapsed:  0:00:00.032016
# Time elapsed:  0:00:00.033354
# Time elapsed:  0:00:00.036516
# Time elapsed:  0:00:00.038189
# Time elapsed:  0:00:00.034419
# Time elapsed:  0:00:00.032802
# Time elapsed:  0:00:00.034530
# Time elapsed:  0:00:00.036935
# Time elapsed:  0:00:00.045622
# Time elapsed:  0:00:00.048324
# Time elapsed:  0:00:00.037501
# Time elapsed:  0:00:00.033505
# Time elapsed:  0:00:00.030017
# Time elapsed:  0:00:00.028818
# Time elapsed:  0:00:00.038648
# Time elapsed:  0:00:00.039275
# Time elapsed:  0:00:00.033962
# Time elapsed:  0:00:00.034755
# Time elapsed:  0:00:00.034266
# Time elapsed:  0:00:00.033555
# Time elapsed:  0:00:00.037990
# Time elapsed:  0:00:00.038138
# Time elapsed:  0:00:00.035976
# Time elapsed:  0:00:00.035807
# Time elapsed:  0:00:00.049249
# Time elapsed:  0:00:00.048481
# Time elapsed:  0:00:00.044752
# Time elapsed:  0:00:00.042928
# Time elapsed:  0:00:00.035001
# Time elapsed:  0:00:00.037246
# Time elapsed:  0:00:00.034240
# Time elapsed:  0:00:00.038295
# Time elapsed:  0:00:00.036502
# Time elapsed:  0:00:00.034526
# Time elapsed:  0:00:00.032632
# Time elapsed:  0:00:00.034385
# Time elapsed:  0:00:00.031783
# Time elapsed:  0:00:00.044890
# Time elapsed:  0:00:00.045781
# Time elapsed:  0:00:00.043759
# Time elapsed:  0:00:00.039419
# Time elapsed:  0:00:00.038514
# Time elapsed:  0:00:00.038066
# Time elapsed:  0:00:00.046717
# Time elapsed:  0:00:00.036185
# Time elapsed:  0:00:00.033841
# Time elapsed:  0:00:00.033079
# Time elapsed:  0:00:00.041080
# Time elapsed:  0:00:00.061447
# Time elapsed:  0:00:00.050118
# Time elapsed:  0:00:00.037046
# Time elapsed:  0:00:00.033926
# Time elapsed:  0:00:00.032054
# Time elapsed:  0:00:00.034722
# Time elapsed:  0:00:00.035441
# Time elapsed:  0:00:00.039023
# Time elapsed:  0:00:00.034081
# Time elapsed:  0:00:00.033244
# Time elapsed:  0:00:00.034618
# Time elapsed:  0:00:00.036350
# Time elapsed:  0:00:00.045201
# Time elapsed:  0:00:00.059128
# Time elapsed:  0:00:00.057678
# Time elapsed:  0:00:00.064044
# Time elapsed:  0:00:00.061236
# Time elapsed:  0:00:00.046902
# Time elapsed:  0:00:00.035763
# Time elapsed:  0:00:00.031895
# Time elapsed:  0:00:00.032580
# Time elapsed:  0:00:00.034123
# Time elapsed:  0:00:00.037562
# Time elapsed:  0:00:00.042677
# Time elapsed:  0:00:00.038504
# Time elapsed:  0:00:00.038211
# Time elapsed:  0:00:00.047624
# Time elapsed:  0:00:00.062841
# Time elapsed:  0:00:00.058177
# Time elapsed:  0:00:00.062327
# Time elapsed:  0:00:00.043426
# Time elapsed:  0:00:00.043956
# Time elapsed:  0:00:00.044097
# Time elapsed:  0:00:00.040581
# Time elapsed:  0:00:00.034743
# Time elapsed:  0:00:00.035997
# Time elapsed:  0:00:00.033589
# Time elapsed:  0:00:00.038793
# Time elapsed:  0:00:00.054806
# Time elapsed:  0:00:00.053974
# Time elapsed:  0:00:00.056896
# Time elapsed:  0:00:00.066071
# Time elapsed:  0:00:00.056281
# Time elapsed:  0:00:00.043086
# Time elapsed:  0:00:00.035201
# Time elapsed:  0:00:00.033882
# Time elapsed:  0:00:00.035807
# Time elapsed:  0:00:00.042187
# Time elapsed:  0:00:00.044595
# Time elapsed:  0:00:00.060512
# Time elapsed:  0:00:00.055440
# Time elapsed:  0:00:00.063412
# Time elapsed:  0:00:00.052730
# Time elapsed:  0:00:00.044016
# Time elapsed:  0:00:00.042006
# Time elapsed:  0:00:00.042118
# Time elapsed:  0:00:00.039113
# Time elapsed:  0:00:00.039843
# Time elapsed:  0:00:00.041186
# Time elapsed:  0:00:00.053900
# Time elapsed:  0:00:00.056552
# Time elapsed:  0:00:00.064708
# Time elapsed:  0:00:00.044413
# Time elapsed:  0:00:00.043097
# Time elapsed:  0:00:00.046652
# Time elapsed:  0:00:00.035565
# Time elapsed:  0:00:00.034035
# Time elapsed:  0:00:00.034317
# Time elapsed:  0:00:00.034526
# Time elapsed:  0:00:00.048886
# Time elapsed:  0:00:00.058650
# Time elapsed:  0:00:00.056977
# Time elapsed:  0:00:00.061160
# Time elapsed:  0:00:00.063691
# Time elapsed:  0:00:00.053570
# Time elapsed:  0:00:00.042668
# Time elapsed:  0:00:00.037663
# Time elapsed:  0:00:00.034079
# Time elapsed:  0:00:00.037888
# Time elapsed:  0:00:00.044959
# Time elapsed:  0:00:00.046555
# Time elapsed:  0:00:00.056524
# Time elapsed:  0:00:00.053666
# Time elapsed:  0:00:00.063380
# Time elapsed:  0:00:00.057845
# Time elapsed:  0:00:00.036783
# Time elapsed:  0:00:00.039722
# Time elapsed:  0:00:00.044395
# Time elapsed:  0:00:00.040582
# Time elapsed:  0:00:00.038052
# Time elapsed:  0:00:00.033966
# Time elapsed:  0:00:00.045338
# Time elapsed:  0:00:00.054878
# Time elapsed:  0:00:00.053000
# Time elapsed:  0:00:00.060800
# Time elapsed:  0:00:00.056110
# Time elapsed:  0:00:00.049846
# Time elapsed:  0:00:00.038518
# Time elapsed:  0:00:00.035848
# Time elapsed:  0:00:00.035143
# Time elapsed:  0:00:00.036274
# Time elapsed:  0:00:00.042264
# Time elapsed:  0:00:00.048756
# Time elapsed:  0:00:00.070277
# Time elapsed:  0:00:00.069986
# Time elapsed:  0:00:00.069547
# Time elapsed:  0:00:00.058985
# Time elapsed:  0:00:00.068141
# Time elapsed:  0:00:00.062517
# Time elapsed:  0:00:00.062680
# Time elapsed:  0:00:00.066614
# Time elapsed:  0:00:00.064558
# Time elapsed:  0:00:00.043629
# Time elapsed:  0:00:00.041087
# Time elapsed:  0:00:00.037189
# Time elapsed:  0:00:00.039475
# Time elapsed:  0:00:00.050715
# Time elapsed:  0:00:00.043771
# Time elapsed:  0:00:00.057933
# Time elapsed:  0:00:00.053772
# Time elapsed:  0:00:00.055817
# Time elapsed:  0:00:00.060592
# Time elapsed:  0:00:00.068257
# Time elapsed:  0:00:00.047268
# Time elapsed:  0:00:00.043219
# Time elapsed:  0:00:00.038411
# Time elapsed:  0:00:00.038589
# Time elapsed:  0:00:00.042354
# Time elapsed:  0:00:00.059472
# Time elapsed:  0:00:00.066222
# Time elapsed:  0:00:00.057606
# Time elapsed:  0:00:00.058092
# Time elapsed:  0:00:00.063408
# Time elapsed:  0:00:00.046798
# Time elapsed:  0:00:00.039154
# Time elapsed:  0:00:00.035772
# Time elapsed:  0:00:00.037437
# Time elapsed:  0:00:00.045392
# Time elapsed:  0:00:00.040939
# Time elapsed:  0:00:00.039022
# Time elapsed:  0:00:00.042328
# Time elapsed:  0:00:00.057174
# Time elapsed:  0:00:00.059257
# Time elapsed:  0:00:00.057046
# Time elapsed:  0:00:00.056856
# Time elapsed:  0:00:00.052840
# Time elapsed:  0:00:00.053851
# Time elapsed:  0:00:00.040618
# Time elapsed:  0:00:00.035311
# Time elapsed:  0:00:00.037347
# Time elapsed:  0:00:00.038630
# Time elapsed:  0:00:00.040122
# Time elapsed:  0:00:00.045107
# Time elapsed:  0:00:00.053585
# Time elapsed:  0:00:00.055810
# Time elapsed:  0:00:00.047696
# Time elapsed:  0:00:00.047525
# Time elapsed:  0:00:00.042164
# Time elapsed:  0:00:00.036417
# Time elapsed:  0:00:00.039775
# Time elapsed:  0:00:00.049235
# Time elapsed:  0:00:00.052758
# Time elapsed:  0:00:00.041451
# Time elapsed:  0:00:00.034626
# Time elapsed:  0:00:00.038058
# Time elapsed:  0:00:00.055370
# Time elapsed:  0:00:00.060558
# Time elapsed:  0:00:00.065574
# Time elapsed:  0:00:00.058467
# Time elapsed:  0:00:00.056479
# Time elapsed:  0:00:00.045505
# Time elapsed:  0:00:00.035654
# Time elapsed:  0:00:00.031636
# Time elapsed:  0:00:00.035614
# Time elapsed:  0:00:00.043038
# Time elapsed:  0:00:00.051782
# Time elapsed:  0:00:00.037557
# Time elapsed:  0:00:00.039365
# Time elapsed:  0:00:00.051793
# Time elapsed:  0:00:00.073461
# Time elapsed:  0:00:00.059428
# Time elapsed:  0:00:00.052566
# Time elapsed:  0:00:00.051811
# Time elapsed:  0:00:00.037354
# Time elapsed:  0:00:00.032305
# Time elapsed:  0:00:00.031896
# Time elapsed:  0:00:00.033500
# Time elapsed:  0:00:00.045119
# Time elapsed:  0:00:00.036929
# Time elapsed:  0:00:00.034260
# Time elapsed:  0:00:00.031953
# Time elapsed:  0:00:00.034749
# Time elapsed:  0:00:00.035534
# Time elapsed:  0:00:00.040468
# Time elapsed:  0:00:00.036804
# Time elapsed:  0:00:00.036374
# Time elapsed:  0:00:00.035611
# Time elapsed:  0:00:00.034374
# Time elapsed:  0:00:00.035002
# Time elapsed:  0:00:00.045164
# Time elapsed:  0:00:00.059885
# Time elapsed:  0:00:00.048999
# Time elapsed:  0:00:00.040375
# Time elapsed:  0:00:00.035542
# Time elapsed:  0:00:00.043092
# Time elapsed:  0:00:00.038323
# Time elapsed:  0:00:00.035941
# Time elapsed:  0:00:00.042288
# Time elapsed:  0:00:00.052093
# Time elapsed:  0:00:00.065911
# Time elapsed:  0:00:00.059056
# Time elapsed:  0:00:00.049588
# Time elapsed:  0:00:00.042306
# Time elapsed:  0:00:00.037117
# Time elapsed:  0:00:00.042228
# Time elapsed:  0:00:00.036087
# Time elapsed:  0:00:00.035677
# Time elapsed:  0:00:00.033979
# Time elapsed:  0:00:00.034071
# Time elapsed:  0:00:00.041834
# Time elapsed:  0:00:00.042294
# Time elapsed:  0:00:00.042316
# Time elapsed:  0:00:00.053542
# Time elapsed:  0:00:00.061327
# Time elapsed:  0:00:00.062930
# Time elapsed:  0:00:00.050945
# Time elapsed:  0:00:00.039659
# Time elapsed:  0:00:00.046884
# Time elapsed:  0:00:00.052548
# Time elapsed:  0:00:00.038858
# Time elapsed:  0:00:00.036804
# Time elapsed:  0:00:00.033870
# Time elapsed:  0:00:00.032647
# Time elapsed:  0:00:00.042293
# Time elapsed:  0:00:00.037297
# Time elapsed:  0:00:00.052083
# Time elapsed:  0:00:00.063548
# Time elapsed:  0:00:00.060645
# Time elapsed:  0:00:00.054914
# Time elapsed:  0:00:00.054612
# Time elapsed:  0:00:00.040754
# Time elapsed:  0:00:00.037595
# Time elapsed:  0:00:00.040642
# Time elapsed:  0:00:00.039373
# Time elapsed:  0:00:00.038463
# Time elapsed:  0:00:00.036338
# Time elapsed:  0:00:00.034065
# Time elapsed:  0:00:00.039689
# Time elapsed:  0:00:00.056178
# Time elapsed:  0:00:00.057313
# Time elapsed:  0:00:00.056319
# Time elapsed:  0:00:00.058636
# Time elapsed:  0:00:00.063583
# Time elapsed:  0:00:00.051705
# Time elapsed:  0:00:00.038555
# Time elapsed:  0:00:00.033883
# Time elapsed:  0:00:00.031316
# Time elapsed:  0:00:00.036565
# Time elapsed:  0:00:00.041957
# Time elapsed:  0:00:00.041691
# Time elapsed:  0:00:00.051682
# Time elapsed:  0:00:00.049987
# Time elapsed:  0:00:00.058918
# Time elapsed:  0:00:00.057314
# Time elapsed:  0:00:00.058056
# Time elapsed:  0:00:00.045896
# Time elapsed:  0:00:00.041454
# Time elapsed:  0:00:00.042340
# Time elapsed:  0:00:00.037943
# Time elapsed:  0:00:00.034051
# Time elapsed:  0:00:00.033334
# Time elapsed:  0:00:00.033053
# Time elapsed:  0:00:00.050150
# Time elapsed:  0:00:00.058480
# Time elapsed:  0:00:00.056362
# Time elapsed:  0:00:00.055870
# Time elapsed:  0:00:00.056555
# Time elapsed:  0:00:00.053161
# Time elapsed:  0:00:00.039767
# Time elapsed:  0:00:00.036752
# Time elapsed:  0:00:00.031118
# Time elapsed:  0:00:00.031199
# Time elapsed:  0:00:00.037882
# Time elapsed:  0:00:00.040678
# Time elapsed:  0:00:00.036260
# Time elapsed:  0:00:00.033416
# Time elapsed:  0:00:00.038106
# Time elapsed:  0:00:00.043707
# Time elapsed:  0:00:00.053047
# Time elapsed:  0:00:00.053108
# Time elapsed:  0:00:00.049551
# Time elapsed:  0:00:00.045736
# Time elapsed:  0:00:00.048954
# Time elapsed:  0:00:00.053891
# Time elapsed:  0:00:00.061419
# Time elapsed:  0:00:00.053505
# Time elapsed:  0:00:00.061550
# Time elapsed:  0:00:00.052264
# Time elapsed:  0:00:00.061983
# Time elapsed:  0:00:00.046679
# Time elapsed:  0:00:00.042174
# Time elapsed:  0:00:00.042391
# Time elapsed:  0:00:00.042287
# Time elapsed:  0:00:00.038678
# Time elapsed:  0:00:00.033827
# Time elapsed:  0:00:00.035200
# Time elapsed:  0:00:00.039576
# Time elapsed:  0:00:00.039906
# Time elapsed:  0:00:00.035608
# Time elapsed:  0:00:00.035395
# Time elapsed:  0:00:00.042371
# Time elapsed:  0:00:00.057260
# Time elapsed:  0:00:00.068121
# Time elapsed:  0:00:00.073740
# Time elapsed:  0:00:00.057773
# Time elapsed:  0:00:00.050362
# Time elapsed:  0:00:00.041273
# Time elapsed:  0:00:00.038069
# Time elapsed:  0:00:00.034984
# Time elapsed:  0:00:00.033738
# Time elapsed:  0:00:00.044898
# Time elapsed:  0:00:00.060364
# Time elapsed:  0:00:00.060681
# Time elapsed:  0:00:00.066165
# Time elapsed:  0:00:00.079049
# Time elapsed:  0:00:00.051982
# Time elapsed:  0:00:00.044569
# Time elapsed:  0:00:00.047333
# Time elapsed:  0:00:00.042520
# Time elapsed:  0:00:00.045288
# Time elapsed:  0:00:00.053869
# Time elapsed:  0:00:00.057611
# Time elapsed:  0:00:00.061646
# Time elapsed:  0:00:00.048626
# Time elapsed:  0:00:00.041009
# Time elapsed:  0:00:00.039230
# Time elapsed:  0:00:00.047006
# Time elapsed:  0:00:00.042398
# Time elapsed:  0:00:00.038846
# Time elapsed:  0:00:00.040616
# Time elapsed:  0:00:00.051427
# Time elapsed:  0:00:00.063721
# Time elapsed:  0:00:00.068188
# Time elapsed:  0:00:00.053717
# Time elapsed:  0:00:00.046391
# Time elapsed:  0:00:00.049018
# Time elapsed:  0:00:00.042209
# Time elapsed:  0:00:00.039569
# Time elapsed:  0:00:00.037540
# Time elapsed:  0:00:00.033840
# Time elapsed:  0:00:00.034061
# Time elapsed:  0:00:00.038784
# Time elapsed:  0:00:00.040992
# Time elapsed:  0:00:00.038849
# Time elapsed:  0:00:00.045705
# Time elapsed:  0:00:00.061509
# Time elapsed:  0:00:00.056108
# Time elapsed:  0:00:00.065197
# Time elapsed:  0:00:00.049392
# Time elapsed:  0:00:00.041670
# Time elapsed:  0:00:00.038869
# Time elapsed:  0:00:00.042156
# Time elapsed:  0:00:00.045869
# Time elapsed:  0:00:00.041468
# Time elapsed:  0:00:00.035608
# Time elapsed:  0:00:00.033945
# Time elapsed:  0:00:00.049192
# Time elapsed:  0:00:00.057081
# Time elapsed:  0:00:00.054856
# Time elapsed:  0:00:00.065746
# Time elapsed:  0:00:00.064051
# Time elapsed:  0:00:00.055055
# Time elapsed:  0:00:00.037740
# Time elapsed:  0:00:00.035578
# Time elapsed:  0:00:00.038550
# Time elapsed:  0:00:00.044558
# Time elapsed:  0:00:00.045419
# Time elapsed:  0:00:00.056907
# Time elapsed:  0:00:00.060207
# Time elapsed:  0:00:00.055314
# Time elapsed:  0:00:00.060921
# Time elapsed:  0:00:00.051546
# Time elapsed:  0:00:00.042103
# Time elapsed:  0:00:00.055235
# Time elapsed:  0:00:00.059606
# Time elapsed:  0:00:00.055828
# Time elapsed:  0:00:00.058446
# Time elapsed:  0:00:00.060374
# Time elapsed:  0:00:00.062702
# Time elapsed:  0:00:00.061882
# Time elapsed:  0:00:00.070058
# Time elapsed:  0:00:00.066226
# Time elapsed:  0:00:00.047665
# Time elapsed:  0:00:00.059430
# Time elapsed:  0:00:00.062028
# Time elapsed:  0:00:00.062037
# Time elapsed:  0:00:00.062565
# Time elapsed:  0:00:00.059388
# Time elapsed:  0:00:00.056751
# Time elapsed:  0:00:00.056610
# Time elapsed:  0:00:00.066350
# Time elapsed:  0:00:00.058475
# Time elapsed:  0:00:00.058130
# Time elapsed:  0:00:00.058517
# Time elapsed:  0:00:00.058294
# Time elapsed:  0:00:00.057957
# Time elapsed:  0:00:00.049126
# Time elapsed:  0:00:00.054258
# Time elapsed:  0:00:00.045296
# Time elapsed:  0:00:00.037961
# Time elapsed:  0:00:00.036779
# Time elapsed:  0:00:00.041243
# Time elapsed:  0:00:00.047927
# Time elapsed:  0:00:00.052308
# Time elapsed:  0:00:00.045416
# Time elapsed:  0:00:00.037430
# Time elapsed:  0:00:00.039011
# Time elapsed:  0:00:00.050189
# Time elapsed:  0:00:00.050171
# Time elapsed:  0:00:00.064050
# Time elapsed:  0:00:00.057662
# Time elapsed:  0:00:00.054732
# Time elapsed:  0:00:00.056783
# Time elapsed:  0:00:00.059513
# Time elapsed:  0:00:00.058441
# Time elapsed:  0:00:00.063586
# Time elapsed:  0:00:00.063854
# Time elapsed:  0:00:00.063530
# Time elapsed:  0:00:00.064634
# Time elapsed:  0:00:00.050911
# Time elapsed:  0:00:00.040920
# Time elapsed:  0:00:00.039605
# Time elapsed:  0:00:00.042693
# Time elapsed:  0:00:00.049423
# Time elapsed:  0:00:00.043567
# Time elapsed:  0:00:00.040008
# Time elapsed:  0:00:00.058905
# Time elapsed:  0:00:00.057202
# Time elapsed:  0:00:00.061253
# Time elapsed:  0:00:00.048574
# Time elapsed:  0:00:00.052060
# Time elapsed:  0:00:00.056497
# Time elapsed:  0:00:00.060488
# Time elapsed:  0:00:00.057977
# Time elapsed:  0:00:00.061986
# Time elapsed:  0:00:00.052229
# Time elapsed:  0:00:00.056303
# Time elapsed:  0:00:00.038566
# Time elapsed:  0:00:00.036207
# Time elapsed:  0:00:00.049474
# Time elapsed:  0:00:00.050629
# Time elapsed:  0:00:00.055310
# Time elapsed:  0:00:00.047399
# Time elapsed:  0:00:00.047645
# Time elapsed:  0:00:00.046451
# Time elapsed:  0:00:00.048089
# Time elapsed:  0:00:00.044140
# Time elapsed:  0:00:00.039076
# Time elapsed:  0:00:00.037709
# Time elapsed:  0:00:00.038231
# Time elapsed:  0:00:00.034611
# Time elapsed:  0:00:00.032896
# Time elapsed:  0:00:00.033043
# Time elapsed:  0:00:00.034148
# Time elapsed:  0:00:00.036497
# Time elapsed:  0:00:00.043952
# Time elapsed:  0:00:00.060364
# Time elapsed:  0:00:00.061979
# Time elapsed:  0:00:00.057385
# Time elapsed:  0:00:00.062804
# Time elapsed:  0:00:00.058652
# Time elapsed:  0:00:00.067153
# Time elapsed:  0:00:00.059311
# Time elapsed:  0:00:00.062055
# Time elapsed:  0:00:00.057454
# Time elapsed:  0:00:00.058021
# Time elapsed:  0:00:00.057538
# Time elapsed:  0:00:00.058128
# Time elapsed:  0:00:00.041834
# Time elapsed:  0:00:00.042166
# Time elapsed:  0:00:00.045973
# Time elapsed:  0:00:00.040138
# Time elapsed:  0:00:00.040345
# Time elapsed:  0:00:00.038173
# Time elapsed:  0:00:00.044698
# Time elapsed:  0:00:00.063966
# Time elapsed:  0:00:00.055251
# Time elapsed:  0:00:00.049695
# Time elapsed:  0:00:00.062723
# Time elapsed:  0:00:00.049733
# Time elapsed:  0:00:00.047413
# Time elapsed:  0:00:00.049844
# Time elapsed:  0:00:00.048975
# Time elapsed:  0:00:00.060083
# Time elapsed:  0:00:00.052962
# Time elapsed:  0:00:00.063368
# Time elapsed:  0:00:00.084760
# Time elapsed:  0:00:00.063933
# Time elapsed:  0:00:00.054548
# Time elapsed:  0:00:00.063682
# Time elapsed:  0:00:00.065078
# Time elapsed:  0:00:00.044789
# Time elapsed:  0:00:00.045272
# Time elapsed:  0:00:00.051056
# Time elapsed:  0:00:00.077421
# Time elapsed:  0:00:00.081252
# Time elapsed:  0:00:00.074142
# Time elapsed:  0:00:00.076339
# Time elapsed:  0:00:00.081069
# Time elapsed:  0:00:00.081526
# Time elapsed:  0:00:00.080750
# Time elapsed:  0:00:00.082562
# Time elapsed:  0:00:00.073451
# Time elapsed:  0:00:00.066937
# Time elapsed:  0:00:00.070457
# Time elapsed:  0:00:00.076847
# Time elapsed:  0:00:00.054821
# Time elapsed:  0:00:00.078963
# Time elapsed:  0:00:00.074124
# Time elapsed:  0:00:00.059287
# Time elapsed:  0:00:00.049245
# Time elapsed:  0:00:00.070776
# Time elapsed:  0:00:00.052805
# Time elapsed:  0:00:00.057732
# Time elapsed:  0:00:00.059446
# Time elapsed:  0:00:00.075140
# Time elapsed:  0:00:00.075948
# Time elapsed:  0:00:00.075976
# Time elapsed:  0:00:00.076946
# Time elapsed:  0:00:00.076269
# Time elapsed:  0:00:00.078346
# Time elapsed:  0:00:00.080551
# Time elapsed:  0:00:00.062949
# Time elapsed:  0:00:00.064777
# Time elapsed:  0:00:00.070016
# Time elapsed:  0:00:00.080824
# Time elapsed:  0:00:00.087087
# Time elapsed:  0:00:00.079226
# Time elapsed:  0:00:00.081606
# Time elapsed:  0:00:00.078952
# Time elapsed:  0:00:00.081321
# Time elapsed:  0:00:00.082162
# Time elapsed:  0:00:00.077786
# Time elapsed:  0:00:00.081519
# Time elapsed:  0:00:00.078360
# Time elapsed:  0:00:00.077528
# Time elapsed:  0:00:00.083497
# Time elapsed:  0:00:00.081332
# Time elapsed:  0:00:00.076753
# Time elapsed:  0:00:00.080440
# Time elapsed:  0:00:00.081375
# Time elapsed:  0:00:00.082560
# Time elapsed:  0:00:00.083330
# Time elapsed:  0:00:00.083440
# Time elapsed:  0:00:00.076105
# Time elapsed:  0:00:00.065241
# Time elapsed:  0:00:00.056825
# Time elapsed:  0:00:00.072632
# Time elapsed:  0:00:00.058838
# Time elapsed:  0:00:00.069067
# Time elapsed:  0:00:00.068060
# Time elapsed:  0:00:00.053574
# Time elapsed:  0:00:00.055750
# Time elapsed:  0:00:00.074639
# Time elapsed:  0:00:00.084754
# Time elapsed:  0:00:00.084407
# Time elapsed:  0:00:00.074086
# Time elapsed:  0:00:00.079921
# Time elapsed:  0:00:00.073539
# Time elapsed:  0:00:00.062069
# Time elapsed:  0:00:00.061408
# Time elapsed:  0:00:00.062986
# Time elapsed:  0:00:00.065588
# Time elapsed:  0:00:00.055486
# Time elapsed:  0:00:00.051003
# Time elapsed:  0:00:00.070740
# Time elapsed:  0:00:00.082103
# Time elapsed:  0:00:00.081340
# Time elapsed:  0:00:00.072094
# Time elapsed:  0:00:00.053268
# Time elapsed:  0:00:00.062942
# Time elapsed:  0:00:00.052999
# Time elapsed:  0:00:00.056777
# Time elapsed:  0:00:00.053605
# Time elapsed:  0:00:00.040372
# Time elapsed:  0:00:00.039191
# Time elapsed:  0:00:00.038004
# Time elapsed:  0:00:00.038505
# Time elapsed:  0:00:00.048133
# Time elapsed:  0:00:00.045345
# Time elapsed:  0:00:00.050219
# Time elapsed:  0:00:00.076242
# Time elapsed:  0:00:00.079378
# Time elapsed:  0:00:00.082880
# Time elapsed:  0:00:00.072862
# Time elapsed:  0:00:00.067648
# Time elapsed:  0:00:00.064928
# Time elapsed:  0:00:00.059711
# Time elapsed:  0:00:00.055864
# Time elapsed:  0:00:00.058409
# Time elapsed:  0:00:00.069821
# Time elapsed:  0:00:00.055189
# Time elapsed:  0:00:00.045308
# Time elapsed:  0:00:00.040825
# Time elapsed:  0:00:00.035826
# Time elapsed:  0:00:00.038350
# Time elapsed:  0:00:00.050756
# Time elapsed:  0:00:00.045012
# Time elapsed:  0:00:00.040280
# Time elapsed:  0:00:00.034432
# Time elapsed:  0:00:00.034400
# Time elapsed:  0:00:00.049575
# Time elapsed:  0:00:00.049147
# Time elapsed:  0:00:00.043595
# Time elapsed:  0:00:00.056366
# Time elapsed:  0:00:00.057672
# Time elapsed:  0:00:00.064794
# Time elapsed:  0:00:00.061745
# Time elapsed:  0:00:00.067680
# Time elapsed:  0:00:00.057751
# Time elapsed:  0:00:00.058458
# Time elapsed:  0:00:00.064168
# Time elapsed:  0:00:00.058575
# Time elapsed:  0:00:00.064177
# Time elapsed:  0:00:00.057244
# Time elapsed:  0:00:00.043137
# Time elapsed:  0:00:00.041147
# Time elapsed:  0:00:00.049010
# Time elapsed:  0:00:00.046081
# Time elapsed:  0:00:00.041970
# Time elapsed:  0:00:00.037293
# Time elapsed:  0:00:00.038767
# Time elapsed:  0:00:00.051380
# Time elapsed:  0:00:00.067517
# Time elapsed:  0:00:00.061191
# Time elapsed:  0:00:00.061789
# Time elapsed:  0:00:00.069044
# Time elapsed:  0:00:00.069231
# Time elapsed:  0:00:00.072371
# Time elapsed:  0:00:00.058554
# Time elapsed:  0:00:00.055895
# Time elapsed:  0:00:00.075419
# Time elapsed:  0:00:00.080466
# Time elapsed:  0:00:00.071049
# Time elapsed:  0:00:00.055404
# Time elapsed:  0:00:00.050122
# Time elapsed:  0:00:00.038253
# Time elapsed:  0:00:00.039071
# Time elapsed:  0:00:00.038137
# Time elapsed:  0:00:00.052235
# Time elapsed:  0:00:00.079747
# Time elapsed:  0:00:00.081763
# Time elapsed:  0:00:00.070343
# Time elapsed:  0:00:00.067759
# Time elapsed:  0:00:00.046508
# Time elapsed:  0:00:00.040898
# Time elapsed:  0:00:00.035924
# Time elapsed:  0:00:00.042165
# Time elapsed:  0:00:00.052135
# Time elapsed:  0:00:00.038406
# Time elapsed:  0:00:00.036888
# Time elapsed:  0:00:00.035068
# Time elapsed:  0:00:00.040358
# Time elapsed:  0:00:00.049563
# Time elapsed:  0:00:00.070142
# Time elapsed:  0:00:00.068958
# Time elapsed:  0:00:00.052755
# Time elapsed:  0:00:00.048780
# Time elapsed:  0:00:00.044042
# Time elapsed:  0:00:00.040852
# Time elapsed:  0:00:00.049015
# Time elapsed:  0:00:00.050293
# Time elapsed:  0:00:00.050180
# Time elapsed:  0:00:00.057779
# Time elapsed:  0:00:00.058138
# Time elapsed:  0:00:00.050472
# Time elapsed:  0:00:00.042868
# Time elapsed:  0:00:00.037209
# Time elapsed:  0:00:00.032961
# Time elapsed:  0:00:00.036681
# Time elapsed:  0:00:00.054189
# Time elapsed:  0:00:00.057232
# Time elapsed:  0:00:00.061141
# Time elapsed:  0:00:00.065928
# Time elapsed:  0:00:00.055753
# Time elapsed:  0:00:00.058827
# Time elapsed:  0:00:00.043044
# Time elapsed:  0:00:00.038700
# Time elapsed:  0:00:00.046560
# Time elapsed:  0:00:00.049034
# Time elapsed:  0:00:00.049108
# Time elapsed:  0:00:00.056277
# Time elapsed:  0:00:00.052936
# Time elapsed:  0:00:00.063401
# Time elapsed:  0:00:00.053165
# Time elapsed:  0:00:00.048028
# Time elapsed:  0:00:00.049779
# Time elapsed:  0:00:00.043991
# Time elapsed:  0:00:00.041070
# Time elapsed:  0:00:00.039046
# Time elapsed:  0:00:00.036838
# Time elapsed:  0:00:00.042802
# Time elapsed:  0:00:00.056239
# Time elapsed:  0:00:00.049728
# Time elapsed:  0:00:00.036146
# Time elapsed:  0:00:00.040669
# Time elapsed:  0:00:00.051474
# Time elapsed:  0:00:00.049108
# Time elapsed:  0:00:00.065026
# Time elapsed:  0:00:00.062521
# Time elapsed:  0:00:00.064278
# Time elapsed:  0:00:00.071739
# Time elapsed:  0:00:00.066931
# Time elapsed:  0:00:00.069223
# Time elapsed:  0:00:00.072953
# Time elapsed:  0:00:00.071489
# Time elapsed:  0:00:00.072959
# Time elapsed:  0:00:00.052376
# Time elapsed:  0:00:00.070982
# Time elapsed:  0:00:00.060093
# Time elapsed:  0:00:00.064781
# Time elapsed:  0:00:00.060553
# Time elapsed:  0:00:00.062982
# Time elapsed:  0:00:00.062409
# Time elapsed:  0:00:00.067682
# Time elapsed:  0:00:00.072529
# Time elapsed:  0:00:00.069294
# Time elapsed:  0:00:00.061792
# Time elapsed:  0:00:00.070905
# Time elapsed:  0:00:00.063186
# Time elapsed:  0:00:00.061787
# Time elapsed:  0:00:00.056368
# Time elapsed:  0:00:00.054012
# Time elapsed:  0:00:00.066247
# Time elapsed:  0:00:00.061909
# Time elapsed:  0:00:00.077412
# Time elapsed:  0:00:00.065922
# Time elapsed:  0:00:00.061782
# Time elapsed:  0:00:00.048109
# Time elapsed:  0:00:00.064961
# Time elapsed:  0:00:00.050469
# Time elapsed:  0:00:00.044351
# Time elapsed:  0:00:00.044274
# Time elapsed:  0:00:00.042324
# Time elapsed:  0:00:00.052176
# Time elapsed:  0:00:00.067660
# Time elapsed:  0:00:00.065593
# Time elapsed:  0:00:00.068260
# Time elapsed:  0:00:00.057616
# Time elapsed:  0:00:00.060840
# Time elapsed:  0:00:00.060624
# Time elapsed:  0:00:00.071166
# Time elapsed:  0:00:00.065494
# Time elapsed:  0:00:00.057473
# Time elapsed:  0:00:00.060153
# Time elapsed:  0:00:00.063192
# Time elapsed:  0:00:00.061175
# Time elapsed:  0:00:00.053631
# Time elapsed:  0:00:00.072227
# Time elapsed:  0:00:00.067852
# Time elapsed:  0:00:00.065274
# Time elapsed:  0:00:00.062664
# Time elapsed:  0:00:00.061713
# Time elapsed:  0:00:00.051793
# Time elapsed:  0:00:00.046641
# Time elapsed:  0:00:00.052447
# Time elapsed:  0:00:00.065471
# Time elapsed:  0:00:00.068666
# Time elapsed:  0:00:00.069412
# Time elapsed:  0:00:00.070074
# Time elapsed:  0:00:00.061688
# Time elapsed:  0:00:00.056493
# Time elapsed:  0:00:00.067035
# Time elapsed:  0:00:00.055808
# Time elapsed:  0:00:00.050452
# Time elapsed:  0:00:00.055903
# Time elapsed:  0:00:00.051714
# Time elapsed:  0:00:00.053380
# Time elapsed:  0:00:00.054323
# Time elapsed:  0:00:00.050530
# Time elapsed:  0:00:00.044949
# Time elapsed:  0:00:00.042538
# Time elapsed:  0:00:00.041713
# Time elapsed:  0:00:00.042697
# Time elapsed:  0:00:00.039111
# Time elapsed:  0:00:00.052440
# Time elapsed:  0:00:00.065108
# Time elapsed:  0:00:00.066156
# Time elapsed:  0:00:00.063725
# Time elapsed:  0:00:00.066206
# Time elapsed:  0:00:00.042702
# Time elapsed:  0:00:00.045382
# Time elapsed:  0:00:00.039845
# Time elapsed:  0:00:00.037649
# Time elapsed:  0:00:00.038024
# Time elapsed:  0:00:00.046730
# Time elapsed:  0:00:00.043926
# Time elapsed:  0:00:00.049577
# Time elapsed:  0:00:00.039675
# Time elapsed:  0:00:00.035637
# Time elapsed:  0:00:00.033677
# Time elapsed:  0:00:00.067178
# Time elapsed:  0:00:00.085166
# Time elapsed:  0:00:00.068397
# Time elapsed:  0:00:00.077407
# Time elapsed:  0:00:00.050515
# Time elapsed:  0:00:00.040792
# Time elapsed:  0:00:00.043552
# Time elapsed:  0:00:00.038703
# Time elapsed:  0:00:00.044141
# Time elapsed:  0:00:00.057030
# Time elapsed:  0:00:00.059872
# Time elapsed:  0:00:00.051224
# Time elapsed:  0:00:00.044076
# Time elapsed:  0:00:00.042173
# Time elapsed:  0:00:00.039132
# Time elapsed:  0:00:00.037410
# Time elapsed:  0:00:00.035000
# Time elapsed:  0:00:00.037856
# Time elapsed:  0:00:00.045994
# Time elapsed:  0:00:00.043729
# Time elapsed:  0:00:00.043345
# Time elapsed:  0:00:00.059167
# Time elapsed:  0:00:00.074594
# Time elapsed:  0:00:00.070575
# Time elapsed:  0:00:00.073045
# Time elapsed:  0:00:00.080366
# Time elapsed:  0:00:00.074131
# Time elapsed:  0:00:00.070028
# Time elapsed:  0:00:00.086279
# Time elapsed:  0:00:00.079966
# Time elapsed:  0:00:00.083605
# Time elapsed:  0:00:00.069968
# Time elapsed:  0:00:00.065626
# Time elapsed:  0:00:00.069876
# Time elapsed:  0:00:00.062751
# Time elapsed:  0:00:00.061437
# Time elapsed:  0:00:00.051253
# Time elapsed:  0:00:00.045529
# Time elapsed:  0:00:00.040188
# Time elapsed:  0:00:00.040229
# Time elapsed:  0:00:00.036159
# Time elapsed:  0:00:00.049924
# Time elapsed:  0:00:00.065808
# Time elapsed:  0:00:00.067365
# Time elapsed:  0:00:00.065099
# Time elapsed:  0:00:00.068965
# Time elapsed:  0:00:00.056651
# Time elapsed:  0:00:00.065528
# Time elapsed:  0:00:00.053128
# Time elapsed:  0:00:00.044833
# Time elapsed:  0:00:00.048259
# Time elapsed:  0:00:00.047929
# Time elapsed:  0:00:00.043947
# Time elapsed:  0:00:00.066030
# Time elapsed:  0:00:00.076485
# Time elapsed:  0:00:00.063135
# Time elapsed:  0:00:00.078175
# Time elapsed:  0:00:00.061502
# Time elapsed:  0:00:00.059146
# Time elapsed:  0:00:00.054257
# Time elapsed:  0:00:00.067620
# Time elapsed:  0:00:00.059240
# Time elapsed:  0:00:00.059112
# Time elapsed:  0:00:00.050479
# Time elapsed:  0:00:00.077924
# Time elapsed:  0:00:00.083326
# Time elapsed:  0:00:00.083635
# Time elapsed:  0:00:00.086510
# Time elapsed:  0:00:00.087180
# Time elapsed:  0:00:00.085439
# Time elapsed:  0:00:00.086619
# Time elapsed:  0:00:00.090893
# Time elapsed:  0:00:00.081061
# Time elapsed:  0:00:00.074023
# Time elapsed:  0:00:00.060392
# Time elapsed:  0:00:00.053368
# Time elapsed:  0:00:00.049941
# Time elapsed:  0:00:00.063514
# Time elapsed:  0:00:00.074156
# Time elapsed:  0:00:00.077877
# Time elapsed:  0:00:00.063432
# Time elapsed:  0:00:00.062343
# Time elapsed:  0:00:00.060090
# Time elapsed:  0:00:00.042923
# Time elapsed:  0:00:00.042753
# Time elapsed:  0:00:00.049036
# Time elapsed:  0:00:00.069780
# Time elapsed:  0:00:00.076939
# Time elapsed:  0:00:00.071933
# Time elapsed:  0:00:00.076364
# Time elapsed:  0:00:00.063392
# Time elapsed:  0:00:00.059768
# Time elapsed:  0:00:00.054272
# Time elapsed:  0:00:00.054597
# Time elapsed:  0:00:00.057220
# Time elapsed:  0:00:00.053689
# Time elapsed:  0:00:00.052833
# Time elapsed:  0:00:00.055337
# Time elapsed:  0:00:00.057174
# Time elapsed:  0:00:00.057868
# Time elapsed:  0:00:00.056956
# Time elapsed:  0:00:00.055844
# Time elapsed:  0:00:00.049421
# Time elapsed:  0:00:00.050205
# Time elapsed:  0:00:00.044872
# Time elapsed:  0:00:00.041250
# Time elapsed:  0:00:00.049948
# Time elapsed:  0:00:00.058283
# Time elapsed:  0:00:00.051016
# Time elapsed:  0:00:00.042103
# Time elapsed:  0:00:00.040102
# Time elapsed:  0:00:00.041667
# Time elapsed:  0:00:00.063737
# Time elapsed:  0:00:00.068683
# Time elapsed:  0:00:00.077653
# Time elapsed:  0:00:00.072404
# Time elapsed:  0:00:00.075006
# Time elapsed:  0:00:00.063999
# Time elapsed:  0:00:00.061356
# Time elapsed:  0:00:00.044504
# Time elapsed:  0:00:00.039748
# Time elapsed:  0:00:00.040987
# Time elapsed:  0:00:00.044380
# Time elapsed:  0:00:00.058298
# Time elapsed:  0:00:00.060882
# Time elapsed:  0:00:00.053961
# Time elapsed:  0:00:00.042187
# Time elapsed:  0:00:00.047668
# Time elapsed:  0:00:00.042675
# Time elapsed:  0:00:00.040602
# Time elapsed:  0:00:00.034038
# Time elapsed:  0:00:00.043625
# Time elapsed:  0:00:00.053230
# Time elapsed:  0:00:00.060834
# Time elapsed:  0:00:00.062399
# Time elapsed:  0:00:00.060510
# Time elapsed:  0:00:00.055326
# Time elapsed:  0:00:00.044863
# Time elapsed:  0:00:00.040344
# Time elapsed:  0:00:00.034155
# Time elapsed:  0:00:00.058953
# Time elapsed:  0:00:00.065704
# Time elapsed:  0:00:00.065222
# Time elapsed:  0:00:00.053745
# Time elapsed:  0:00:00.057688
# Time elapsed:  0:00:00.058350
# Time elapsed:  0:00:00.053896
# Time elapsed:  0:00:00.055414
# Time elapsed:  0:00:00.052679
# Time elapsed:  0:00:00.046487
# Time elapsed:  0:00:00.044055
# Time elapsed:  0:00:00.042843
# Time elapsed:  0:00:00.046304
# Time elapsed:  0:00:00.055279
# Time elapsed:  0:00:00.069412
# Time elapsed:  0:00:00.053039
# Time elapsed:  0:00:00.049077
# Time elapsed:  0:00:00.048774
# Time elapsed:  0:00:00.048718
# Time elapsed:  0:00:00.042587
# Time elapsed:  0:00:00.054200
# Time elapsed:  0:00:00.076000
# Time elapsed:  0:00:00.073388
# Time elapsed:  0:00:00.083209
# Time elapsed:  0:00:00.083064
# Time elapsed:  0:00:00.061954
# Time elapsed:  0:00:00.057310
# Time elapsed:  0:00:00.055084
# Time elapsed:  0:00:00.057417
# Time elapsed:  0:00:00.046657
# Time elapsed:  0:00:00.042794
# Time elapsed:  0:00:00.041820
# Time elapsed:  0:00:00.036406
# Time elapsed:  0:00:00.038947
# Time elapsed:  0:00:00.045620
# Time elapsed:  0:00:00.059525
# Time elapsed:  0:00:00.056538
# Time elapsed:  0:00:00.052867
# Time elapsed:  0:00:00.050201
# Time elapsed:  0:00:00.040925
# Time elapsed:  0:00:00.035498
# Time elapsed:  0:00:00.034828
# Time elapsed:  0:00:00.033552
# Time elapsed:  0:00:00.072342
# Time elapsed:  0:00:00.057081
# Time elapsed:  0:00:00.057690
# Time elapsed:  0:00:00.060226
# Time elapsed:  0:00:00.063635
# Time elapsed:  0:00:00.062649
# Time elapsed:  0:00:00.048019
# Time elapsed:  0:00:00.038939
# Time elapsed:  0:00:00.034814
# Time elapsed:  0:00:00.045603
# Time elapsed:  0:00:00.051765
# Time elapsed:  0:00:00.046015
# Time elapsed:  0:00:00.042309
# Time elapsed:  0:00:00.036089
# Time elapsed:  0:00:00.035792
# Time elapsed:  0:00:00.042089
# Time elapsed:  0:00:00.053039
# Time elapsed:  0:00:00.059360
# Time elapsed:  0:00:00.065363
# Time elapsed:  0:00:00.054594
# Time elapsed:  0:00:00.047619
# Time elapsed:  0:00:00.047192
# Time elapsed:  0:00:00.044718
# Time elapsed:  0:00:00.060297
# Time elapsed:  0:00:00.070862
# Time elapsed:  0:00:00.069299
# Time elapsed:  0:00:00.069933
# Time elapsed:  0:00:00.063464
# Time elapsed:  0:00:00.065669
# Time elapsed:  0:00:00.063176
# Time elapsed:  0:00:00.060969
# Time elapsed:  0:00:00.044269
# Time elapsed:  0:00:00.037928
# Time elapsed:  0:00:00.034722
# Time elapsed:  0:00:00.047513
# Time elapsed:  0:00:00.067179
# Time elapsed:  0:00:00.073299
# Time elapsed:  0:00:00.080331
# Time elapsed:  0:00:00.058206
# Time elapsed:  0:00:00.048467
# Time elapsed:  0:00:00.044763
# Time elapsed:  0:00:00.049992
# Time elapsed:  0:00:00.069946
# Time elapsed:  0:00:00.067627
# Time elapsed:  0:00:00.071863
# Time elapsed:  0:00:00.082486
# Time elapsed:  0:00:00.076605
# Time elapsed:  0:00:00.052583
# Time elapsed:  0:00:00.043465
# Time elapsed:  0:00:00.044196
# Time elapsed:  0:00:00.044677
# Time elapsed:  0:00:00.038386
# Time elapsed:  0:00:00.041495
# Time elapsed:  0:00:00.037190
# Time elapsed:  0:00:00.049411
# Time elapsed:  0:00:00.077317
# Time elapsed:  0:00:00.064621
# Time elapsed:  0:00:00.065853
# Time elapsed:  0:00:00.051274
# Time elapsed:  0:00:00.043312
# Time elapsed:  0:00:00.043296
# Time elapsed:  0:00:00.037112
# Time elapsed:  0:00:00.039347
# Time elapsed:  0:00:00.050935
# Time elapsed:  0:00:00.040462
# Time elapsed:  0:00:00.038195
# Time elapsed:  0:00:00.049890
# Time elapsed:  0:00:00.065311
# Time elapsed:  0:00:00.056734
# Time elapsed:  0:00:00.062480
# Time elapsed:  0:00:00.065528
# Time elapsed:  0:00:00.072965
# Time elapsed:  0:00:00.071035
# Time elapsed:  0:00:00.060863
# Time elapsed:  0:00:00.072424
# Time elapsed:  0:00:00.066888
# Time elapsed:  0:00:00.073078
# Time elapsed:  0:00:00.078018
# Time elapsed:  0:00:00.069463
# Time elapsed:  0:00:00.046027
# Time elapsed:  0:00:00.043093
# Time elapsed:  0:00:00.057917
# Time elapsed:  0:00:00.068304
# Time elapsed:  0:00:00.066020
# Time elapsed:  0:00:00.065842
# Time elapsed:  0:00:00.063905
# Time elapsed:  0:00:00.069195
# Time elapsed:  0:00:00.081196
# Time elapsed:  0:00:00.058775
# Time elapsed:  0:00:00.062593
# Time elapsed:  0:00:00.051759
# Time elapsed:  0:00:00.047135
# Time elapsed:  0:00:00.061219
# Time elapsed:  0:00:00.042707
# Time elapsed:  0:00:00.039382
# Time elapsed:  0:00:00.036909
# Time elapsed:  0:00:00.042513
# Time elapsed:  0:00:00.054421
# Time elapsed:  0:00:00.059775
# Time elapsed:  0:00:00.053600
# Time elapsed:  0:00:00.045124
# Time elapsed:  0:00:00.044700
# Time elapsed:  0:00:00.039186
# Time elapsed:  0:00:00.037860
# Time elapsed:  0:00:00.035304
# Time elapsed:  0:00:00.033436
# Time elapsed:  0:00:00.041248
# Time elapsed:  0:00:00.046041
# Time elapsed:  0:00:00.039892
# Time elapsed:  0:00:00.037309
# Time elapsed:  0:00:00.034701
# Time elapsed:  0:00:00.043776
# Time elapsed:  0:00:00.065437
# Time elapsed:  0:00:00.069824
# Time elapsed:  0:00:00.071830
# Time elapsed:  0:00:00.073215
# Time elapsed:  0:00:00.069058
# Time elapsed:  0:00:00.069343
# Time elapsed:  0:00:00.055983
# Time elapsed:  0:00:00.042858
# Time elapsed:  0:00:00.036407
# Time elapsed:  0:00:00.033117
# Time elapsed:  0:00:00.036103
# Time elapsed:  0:00:00.043533
# Time elapsed:  0:00:00.055114
# Time elapsed:  0:00:00.072854
# Time elapsed:  0:00:00.069233
# Time elapsed:  0:00:00.069585
# Time elapsed:  0:00:00.084904
# Time elapsed:  0:00:00.077265
# Time elapsed:  0:00:00.078378
# Time elapsed:  0:00:00.071658
# Time elapsed:  0:00:00.082919
# Time elapsed:  0:00:00.071904
# Time elapsed:  0:00:00.074766
# Time elapsed:  0:00:00.066632
# Time elapsed:  0:00:00.079464
# Time elapsed:  0:00:00.068588
# Time elapsed:  0:00:00.076827
# Time elapsed:  0:00:00.073936
# Time elapsed:  0:00:00.067885
# Time elapsed:  0:00:00.089557
# Time elapsed:  0:00:00.071964
# Time elapsed:  0:00:00.077463
# Time elapsed:  0:00:00.093784
# Time elapsed:  0:00:00.083152
# Time elapsed:  0:00:00.088273
# Time elapsed:  0:00:00.083767
# Time elapsed:  0:00:00.079679
# Time elapsed:  0:00:00.071432
# Time elapsed:  0:00:00.077481
# Time elapsed:  0:00:00.072441
# Time elapsed:  0:00:00.082230
# Time elapsed:  0:00:00.085789
# Time elapsed:  0:00:00.088114
# Time elapsed:  0:00:00.087393
# Time elapsed:  0:00:00.080219
# Time elapsed:  0:00:00.081913
# Time elapsed:  0:00:00.078809
# Time elapsed:  0:00:00.081986
# Time elapsed:  0:00:00.083423
# Time elapsed:  0:00:00.097005
# Time elapsed:  0:00:00.085816
# Time elapsed:  0:00:00.081443
# Time elapsed:  0:00:00.083932
# Time elapsed:  0:00:00.090440
# Time elapsed:  0:00:00.085538
# Time elapsed:  0:00:00.090640
# Time elapsed:  0:00:00.087015
# Time elapsed:  0:00:00.084910
# Time elapsed:  0:00:00.081204
# Time elapsed:  0:00:00.095239
# Time elapsed:  0:00:00.083904
# Time elapsed:  0:00:00.084842
# Time elapsed:  0:00:00.085715
# Time elapsed:  0:00:00.082864
# Time elapsed:  0:00:00.075887
# Time elapsed:  0:00:00.070288
# Time elapsed:  0:00:00.067488
# Time elapsed:  0:00:00.061469
# Time elapsed:  0:00:00.051489
# Time elapsed:  0:00:00.051649
# Time elapsed:  0:00:00.062802
# Time elapsed:  0:00:00.072642
# Time elapsed:  0:00:00.048446
# Time elapsed:  0:00:00.046556
# Time elapsed:  0:00:00.056781
# Time elapsed:  0:00:00.045745
# Time elapsed:  0:00:00.041548
# Time elapsed:  0:00:00.044113
# Time elapsed:  0:00:00.058233
# Time elapsed:  0:00:00.046828
# Time elapsed:  0:00:00.041409
# Time elapsed:  0:00:00.038410
# Time elapsed:  0:00:00.046108
# Time elapsed:  0:00:00.050969
# Time elapsed:  0:00:00.049677
# Time elapsed:  0:00:00.040043
# Time elapsed:  0:00:00.038126
# Time elapsed:  0:00:00.047838
# Time elapsed:  0:00:00.052952
# Time elapsed:  0:00:00.046398
# Time elapsed:  0:00:00.042359
# Time elapsed:  0:00:00.035819
# Time elapsed:  0:00:00.044822
# Time elapsed:  0:00:00.053398
# Time elapsed:  0:00:00.045291
# Time elapsed:  0:00:00.042763
# Time elapsed:  0:00:00.038656
# Time elapsed:  0:00:00.042876
# Time elapsed:  0:00:00.055065
# Time elapsed:  0:00:00.048499
# Time elapsed:  0:00:00.038668
# Time elapsed:  0:00:00.035244
# Time elapsed:  0:00:00.039833
# Time elapsed:  0:00:00.054078
# Time elapsed:  0:00:00.045200
# Time elapsed:  0:00:00.038200
# Time elapsed:  0:00:00.036775
# Time elapsed:  0:00:00.037043
# Time elapsed:  0:00:00.043856
# Time elapsed:  0:00:00.054280
# Time elapsed:  0:00:00.042170
# Time elapsed:  0:00:00.049824
# Time elapsed:  0:00:00.068716
# Time elapsed:  0:00:00.068193
# Time elapsed:  0:00:00.070370
# Time elapsed:  0:00:00.080525
# Time elapsed:  0:00:00.067597
# Time elapsed:  0:00:00.080043
# Time elapsed:  0:00:00.079335
# Time elapsed:  0:00:00.076201
# Time elapsed:  0:00:00.075769
# Time elapsed:  0:00:00.069363
# Time elapsed:  0:00:00.073182
# Time elapsed:  0:00:00.080156
# Time elapsed:  0:00:00.080718
# Time elapsed:  0:00:00.080179
# Time elapsed:  0:00:00.076820
# Time elapsed:  0:00:00.076079
# Time elapsed:  0:00:00.076297
# Time elapsed:  0:00:00.065859
# Time elapsed:  0:00:00.065121
# Time elapsed:  0:00:00.082722
# Time elapsed:  0:00:00.094233
# Time elapsed:  0:00:00.071730
# Time elapsed:  0:00:00.083949
# Time elapsed:  0:00:00.094376
# Time elapsed:  0:00:00.077317
# Time elapsed:  0:00:00.076069
# Time elapsed:  0:00:00.075855
# Time elapsed:  0:00:00.074435
# Time elapsed:  0:00:00.089166
# Time elapsed:  0:00:00.079000
# Time elapsed:  0:00:00.071353
# Time elapsed:  0:00:00.071754
# Time elapsed:  0:00:00.077186
# Time elapsed:  0:00:00.074916
# Time elapsed:  0:00:00.073244
# Time elapsed:  0:00:00.062022
# Time elapsed:  0:00:00.071705
# Time elapsed:  0:00:00.066894
# Time elapsed:  0:00:00.073330
# Time elapsed:  0:00:00.068832
# Time elapsed:  0:00:00.051030
# Time elapsed:  0:00:00.053982
# Time elapsed:  0:00:00.060091
# Time elapsed:  0:00:00.057314
# Time elapsed:  0:00:00.053041
# Time elapsed:  0:00:00.055272
# Time elapsed:  0:00:00.061540
# Time elapsed:  0:00:00.053362
# Time elapsed:  0:00:00.055734
# Time elapsed:  0:00:00.054002
# Time elapsed:  0:00:00.047311
# Time elapsed:  0:00:00.052158
# Time elapsed:  0:00:00.055549
# Time elapsed:  0:00:00.050440
# Time elapsed:  0:00:00.049429
# Time elapsed:  0:00:00.052881
# Time elapsed:  0:00:00.055479
# Time elapsed:  0:00:00.060438
# Time elapsed:  0:00:00.058982
# Time elapsed:  0:00:00.057281
# Time elapsed:  0:00:00.067211
# Time elapsed:  0:00:00.056875
# Time elapsed:  0:00:00.064435
# Time elapsed:  0:00:00.075313
# Time elapsed:  0:00:00.065999
# Time elapsed:  0:00:00.065029
# Time elapsed:  0:00:00.062549
# Time elapsed:  0:00:00.057634
# Time elapsed:  0:00:00.061526
# Time elapsed:  0:00:00.059369
# Time elapsed:  0:00:00.058682
# Time elapsed:  0:00:00.063703
# Time elapsed:  0:00:00.056959
# Time elapsed:  0:00:00.045350
# Time elapsed:  0:00:00.049650
# Time elapsed:  0:00:00.041511
# Time elapsed:  0:00:00.039464
# Time elapsed:  0:00:00.038861
# Time elapsed:  0:00:00.057220
# Time elapsed:  0:00:00.069165
# Time elapsed:  0:00:00.074483
# Time elapsed:  0:00:00.085050
# Time elapsed:  0:00:00.067864
# Time elapsed:  0:00:00.052715
# Time elapsed:  0:00:00.041070
# Time elapsed:  0:00:00.041308
# Time elapsed:  0:00:00.049544
# Time elapsed:  0:00:00.063117
# Time elapsed:  0:00:00.057275
# Time elapsed:  0:00:00.067581
# Time elapsed:  0:00:00.065137
# Time elapsed:  0:00:00.056048
# Time elapsed:  0:00:00.045545
# Time elapsed:  0:00:00.042350
# Time elapsed:  0:00:00.047479
# Time elapsed:  0:00:00.042568
# Time elapsed:  0:00:00.038638
# Time elapsed:  0:00:00.039008
# Time elapsed:  0:00:00.050056
# Time elapsed:  0:00:00.059011
# Time elapsed:  0:00:00.041740
# Time elapsed:  0:00:00.035559
# Time elapsed:  0:00:00.038603
# Time elapsed:  0:00:00.052388
# Time elapsed:  0:00:00.063240
# Time elapsed:  0:00:00.074933
# Time elapsed:  0:00:00.076706
# Time elapsed:  0:00:00.072454
# Time elapsed:  0:00:00.080462
# Time elapsed:  0:00:00.070395
# Time elapsed:  0:00:00.062004
# Time elapsed:  0:00:00.049463
# Time elapsed:  0:00:00.041380
# Time elapsed:  0:00:00.038813
# Time elapsed:  0:00:00.045904
# Time elapsed:  0:00:00.044977
# Time elapsed:  0:00:00.038884
# Time elapsed:  0:00:00.039197
# Time elapsed:  0:00:00.039438
# Time elapsed:  0:00:00.034534
# Time elapsed:  0:00:00.043659
# Time elapsed:  0:00:00.042845
# Time elapsed:  0:00:00.039428
# Time elapsed:  0:00:00.051881
# Time elapsed:  0:00:00.054337
# Time elapsed:  0:00:00.046475
# Time elapsed:  0:00:00.039195
# Time elapsed:  0:00:00.035286
# Time elapsed:  0:00:00.031882
# Time elapsed:  0:00:00.033775
# Time elapsed:  0:00:00.034281
# Time elapsed:  0:00:00.035984
# Time elapsed:  0:00:00.039833
# Time elapsed:  0:00:00.039755
# Time elapsed:  0:00:00.039873
# Time elapsed:  0:00:00.044466
# Time elapsed:  0:00:00.069210
# Time elapsed:  0:00:00.065838
# Time elapsed:  0:00:00.069102
# Time elapsed:  0:00:00.066154
# Time elapsed:  0:00:00.058035
# Time elapsed:  0:00:00.047054
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 fmd1.eval()
#
# Input In [1], in FMD.eval(self)
#     766 if is_there_eval_name_prev_EFMPI_k_pickle:
#     767     with open(f'{eval_dir}/{eval_name}_{prev_EFMPI_k}.pickle', 'rb') as f:
# --> 768         EFMP_k = pickle.load(f)
#     769 # {eval_name}_{prev_EFMPI_k}.pickle가 없다면
#     770 # eval_{prev_EFMPI_k}.pickle 파일을 가지고 온다.
#     771 else:
#     772     with open(f'{eval_dir}/eval_{prev_EFMPI_k}.pickle', 'rb') as f:
#
# KeyboardInterrupt:

# %%
fmd1.show_eval_infos()

# %%
a = np.load('/Volumes/My Passport_ssd_sg3/data_sets/fmnist/shirts/eval/rotation_90/rotation_90_result.npy')

# %%
print(len(a))
print(len(np.nonzero(a)[0]))
print(len(a)-len(np.nonzero(a)[0]))

# %%
start = time.process_time()

with open(f'/Volumes/My Passport_ssd_sg3/data_sets/fmnist/shirts/eval/brightness_10/brightness_10_0.pickle', 'rb') as f:
    EFMP_k = pickle.load(f)

end = time.process_time()
print("Time elapsed: ", timedelta(seconds=end-start))
    
start = time.process_time()

a = EFMP_k[0]

end = time.process_time()
print("Time elapsed: ", timedelta(seconds=end-start))
# Out:
# Time elapsed:  0:00:01.071915
# Time elapsed:  0:00:00.000200
