# %% [markdown]
# # resnet 모델 가지고 오기

# %%
from torchvision import models
from torchsummary import summary
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # 학습 환경 설정
model = models.resnet50(pretrained=True).to(device) # true 옵션으로 사전 학습된 모델을 로드

summary(model, (3, 128, 128))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 64, 64]           9,408
#        BatchNorm2d-2           [-1, 64, 64, 64]             128
#               ReLU-3           [-1, 64, 64, 64]               0
#          MaxPool2d-4           [-1, 64, 32, 32]               0
#             Conv2d-5           [-1, 64, 32, 32]           4,096
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#               ReLU-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#              ReLU-10           [-1, 64, 32, 32]               0
# ...

# %% [markdown]
# # 데이터 셋 가지고 오기

# %% [markdown]
# 1. keras.datasets에 있는 cifar10 데이터 셋

# %%
from keras.datasets import cifar10
# cifar 데이터 불러오기
(X_train_cifar10, y_train_cifar10), (X_test_cifar10, y_test_cifar10) = cifar10.load_data()
# Out:
# ...
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
print(X_train_cifar10.shape)
print(y_train_cifar10.shape)
print(X_test_cifar10.shape)
print(y_test_cifar10.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# 2. keras.datasets에 있는 fashion mnist 가지고 오기

# %%
from keras.datasets import fashion_mnist
# fashion_mnist 데이터 불러오기
(X_train_fashion_mnist, y_train_fashion_mnist), (X_test_fashion_mnist, y_test_fashion_mnist) = fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# 3. stl-10 데이터 셋 가지고 오기

# %%
# loading training data
import torchvision.transforms as transforms
from torchvision.datasets import STL10
import os

path2data = './data'

# if not exists the path, make the path
if not os.path.exists(path2data):
    os.mkdir(path2data)

data_transformer = transforms.Compose([transforms.ToTensor()])
train_ds = STL10(path2data, split='train', download='True', transform=data_transformer)

print(train_ds.data.shape)
# Out:
# ...
#   0%|          | 0/2640397119 [00:00<?, ?it/s]
# Extracting ./data/stl10_binary.tar.gz to ./data
# (5000, 3, 96, 96)

# %%
import collections
y_train = [y for _,y in train_ds]
counter_train = collections.Counter(y_train)
print(counter_train)
# Out:
# Counter({1: 500, 5: 500, 6: 500, 3: 500, 9: 500, 7: 500, 4: 500, 8: 500, 0: 500, 2: 500})

# %%
# load test dataset and call it test0_ds
test0_ds = STL10(path2data, split='test', download=True, transform=data_transformer)
print(test0_ds.data.shape)
# Out:
# Files already downloaded and verified
# (8000, 3, 96, 96)
